# %%
from IPython.core.magic import register_cell_magic

@register_cell_magic
def skip(line, cell):
    return

# %%
from azure.cosmos import CosmosClient, exceptions, PartitionKey
import json
from azure.identity import DefaultAzureCredential
import os
import openai_helper 
import nest_asyncio
import asyncio

# Define your Cosmos DB account information
endpoint = "https://anildwacosmoswestus.documents.azure.com:443/"


# Initialize the Cosmos client
client = CosmosClient(endpoint, credential=DefaultAzureCredential())

# %%
database_name = 'booksdb'
container_name = 'books_perftest'

client.create_database_if_not_exists(id=database_name)
# Connect to the database and container
database = client.get_database_client(database_name)

# %%
vector_embedding_policy = {
    "vectorEmbeddings": [
        {
            "path":"/textVector",
            "dataType":"float32",
            "distanceFunction":"cosine",
            "dimensions":1536
        }
    ]
}


vector_indexing_policy = {
    
    "indexingMode": "consistent",
    "automatic": True,
    "includedPaths": [
        {
            "path": "/*"
        }
    ],
    "excludedPaths": [
        {
            "path": "/_etag/?"
        },
        {
            "path": "/textVector/*"
        }
        
    ],
    "vectorIndexes": [
        {
            "path": "/textVector",
            "type": "quantizedFlat"
        }
    ]
}

full_text_paths_policy = {
   "defaultLanguage": "en-US",
   "fullTextPaths": [
       {
           "path": "/fileName",
           "language": "en-US"
       },
       {
           "path": "/text",
           "language": "en-US"
       }
   ]
}




vector_indexing_policy_diskANN = {
    
    "indexingMode": "consistent",
    "automatic": True,
    "includedPaths": [
        {
            "path": "/*"
        }
    ],
    "excludedPaths": [
        {
            "path": "/_etag/?"
        },
        {
            "path": "/textVector/*"
        }
    ],
    "fullTextIndexes": [
        {
            "path": "/text"
        }
    ],
    "vectorIndexes": [
        {
            "path": "/textVector",
            "type": "diskANN"
        }
    ]
}

# %%
for db in client.list_databases():
    print(db)
# Out:
# {'id': 'booksdb', '_rid': 'adFqAA==', '_self': 'dbs/adFqAA==/', '_etag': '"00008a00-0000-0700-0000-680936200000"', '_colls': 'colls/', '_users': 'users/', '_ts': 1745434144}

# %%
#database.delete_container(container=container_name)

# %%
container_name = "books_perftest"

# %%
#container_name = "books_small"

# %%
container = None
try:
    container = database.create_container(id=container_name, partition_key=PartitionKey(path="/id"), 
                          vector_embedding_policy=vector_embedding_policy,
                          indexing_policy=vector_indexing_policy_diskANN,
                          full_text_policy=full_text_paths_policy,
                          offer_throughput=10000) 
except exceptions.CosmosResourceExistsError:
    print(f"Container {container_name} already exists. Using existing container.")
    container = database.get_container_client(container_name)
# Out:
# Container books_perftest already exists. Using existing container.

# %%
# %%skip
#
# # read csv files
# import os
# import pandas as pd
# import uuid
# import tiktoken
#
# encoding = tiktoken.encoding_for_model("text-embedding-ada-002")
#
# MAX_TOKENS = 8192
#
# count = 0
# total=len(os.listdir('q1_files'))
# data = []
# for file in os.listdir('q1_files'):
#     df = pd.read_csv('q1_files/' + file)
#     text = df['text'].iloc[0]
#     #embedding_result = await openai_helper.generate_embeddings([df['text'].iloc[0]])
#     tokens = encoding.encode(text)
#     token_length = len(tokens)
#
#     if len(tokens) > MAX_TOKENS:
#         tokens = tokens[:MAX_TOKENS]
#         text = encoding.decode(tokens)
#
#     print(f"Trimmed token length: {len(tokens)}")
#     print(f"Trimmed text: {text[:300]}...")  # Show sample
#     book_item = {
#         "id": str(uuid.uuid4()),
#         "fileName": file,
#         "text": df['text'].iloc[0],
#         "textVector": embedding_result[0].embedding,
#     }
#     print(token_length)
#     break
#     #data.append(book_item)
#     #res = container.upsert_item(book_item)
#
#
#
# #res = await container.upsert_item(book_item)
# #count += 1
# #print(f"processing {count} of {total}")

# %%
# %%skip
# with open('q1.txt', 'r') as file:
#     q1_lines = [line.strip() for line in file if line.strip()]
#
# # Flatten multi-line entries (like Janet_My_Mother_and_Me.csv)
# from itertools import groupby
#
# q1_files = []
# temp = []
# for line in q1_lines:
#     temp.append(line)
#     if line.endswith('.csv'):
#         q1_files.append('_'.join(temp))
#         temp = []

# %% [markdown]
# ## Vector Search + Full Text Search

# %%
questions_path = 'questions'

questions = [
    "Give me a list of books published in the year 2000",
"Give me a list of book of travel category",
"Give me a list of books from author Agatha Christie",
"Give me some haunted incidents from california state",
"Give me some wines found in Italy",
"Give me wines tasted by Roger Voss",
"Give me some wines in the variety of Red Blend",
"Give me some business category news",
"Give me a list of students graduated in the year 2025"]

questions_with_topk = []

import os

for index, f in enumerate(os.listdir(questions_path)):
    with open(os.path.join(questions_path, f), 'r', encoding='utf-8') as file:
        q1_lines = [line.strip() for line in file if line.strip()]
        number_of_lines = len(q1_lines)
        
        q = {"question" : questions[index], "topk": number_of_lines}
        questions_with_topk.append(q)
        
        # Flatten multi-line entries (like Janet_My_Mother

# %%
questions_with_topk
# Out:
# [{'question': 'Give me a list of books published in the year 2000',
#   'topk': 326},
#  {'question': 'Give me a list of book of travel category', 'topk': 41},
#  {'question': 'Give me a list of books from author Agatha Christie',
#   'topk': 37},
#  {'question': 'Give me some haunted incidents from california state',
#   'topk': 88},
#  {'question': 'Give me some wines found in Italy', 'topk': 181},
#  {'question': 'Give me wines tasted by Roger Voss', 'topk': 98},
#  {'question': 'Give me some wines in the variety of Red Blend', 'topk': 452},
#  {'question': 'Give me some business category news', 'topk': 501},
#  {'question': 'Give me a list of students graduated in the year 2025',
#   'topk': 32}]

# %%
def query_with_filename(file_name):
  items = container.query_items( 
  query=f"""SELECT top 20 c.fileName FROM c WHERE c.fileName = '{file_name}'
  """, 
  parameters=[ 
    #{"name": "@embedding", "value": search_query_embedded} 
  ], 
  enable_cross_partition_query=True)


  for item in items:
      print(item)

# %% [markdown]
# ## Methods

# %%
import asyncio
import httpx
import requests
import json
import re

def extract_csv_filenames(context_text):
    # Match any CSV filename starting with allowed prefixes
    return re.findall(r'(?:book|wine|haunted|news|student|legal)_[^\\"]+\.csv', context_text)

async def call_lazygraph_api(user_query):
    url = "http://10.0.0.9:8760/api/query"
    headers = {
        'Content-Type': 'application/json',
    }
    data = {
        "user_query": user_query
    }

    timeout = httpx.Timeout(300.0)
    async with httpx.AsyncClient(timeout=timeout) as client:
        response = await client.post(url, headers=headers, json=data)

        if response.status_code == 200:
            response_data = response.json()
            context_files = json.loads(response_data["context_text"])
            file_names = []
            seen = set()

            for file_text in context_files:
                for fname in extract_csv_filenames(file_text):
                    if fname not in seen:
                        seen.add(fname)
                        file_names.append({"fileName": fname})

            print(f"LazyGraph API response: {len(file_names)} files found")
            for file in file_names:
                print(f"File: {file['fileName']}")

            return file_names
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None



async def get_vector_search_results(container_name, embedding_model, search_query, top_k=5, threshold=0.7):
    embedding_result = await openai_helper.get_embeddings([search_query], model=embedding_model)
    search_query_embedded = embedding_result # embedding_result[0].embedding
    def run_query():
        
        container = database.get_container_client(container_name)    
        items = container.query_items( 
            query="""
            SELECT top @top_k c.fileName, VectorDistance(c.textVector, @embedding) AS textSimilarityScore 
            FROM c
            WHERE VectorDistance(c.textVector, @embedding) > @threshold
            ORDER BY VectorDistance(c.textVector, @embedding) 
            """, 
            parameters=[
                {"name": "@embedding", "value": search_query_embedded},
                {"name": "@top_k", "value": top_k},
                {"name": "@threshold", "value": threshold}
            ], 
            enable_cross_partition_query=True)
        return [item for item in items]

    return await asyncio.to_thread(run_query)


async def get_fulltext_search_results(container_name, search_query, top_k=5):
    def run_query():
        container = database.get_container_client(container_name)
        search_query_arr = search_query.split(" ")
        #print(search_query_arr)
        query_string = f"""
        SELECT TOP @top_k c.fileName
        FROM c
        ORDER BY RANK FullTextScore(c.text, {search_query_arr})
        """

        items = container.query_items(
            query=query_string,
            parameters=[
                {"name": "@top_k", "value": top_k},
            ],
            enable_cross_partition_query=True
        )

        item_files = [item for item in items]
        return item_files

    return await asyncio.to_thread(run_query)

async def get_fulltext_all_search_results(container, search_query, top_k=5):
    search_query_arr = search_query.split(" ")
    #print(search_query_arr)
    query_string = f"""
    SELECT TOP @top_k c.fileName
    FROM c
    WHERE FullTextContainsAll(c.text, {search_query_arr})
    """

    items = container.query_items(
        query=query_string,
        parameters=[
            {"name": "@top_k", "value": top_k},
        ],
        enable_cross_partition_query=True
    )

    item_files = [item for item in items]
    return item_files

def combine_search_results(vector_results, fulltext_results):
    file_names_vector = {item['fileName'] for item in vector_results}
    file_names_fts = {item['fileName'] for item in fulltext_results}

    # Union of the two sets
    union_file_names = file_names_vector.union(file_names_fts)

    # Convert to sorted list of dicts with only fileName field
    union_items = [{'fileName': name} for name in sorted(union_file_names)]

    return union_items
    # Print result
    #print(f"Total unique items in union: {len(union_items)}")
    #for item in union_items:
    #    print(item)



    


def combine_search_results_with_lgr(vector_results, fulltext_results, lgr_results):
    file_names_vector = {item['fileName'] for item in vector_results}
    file_names_fts = {item['fileName'] for item in fulltext_results}
    file_names_lgr = {item['fileName'] for item in lgr_results}

    # Union of the two sets
    union_file_names = file_names_vector.union(file_names_fts).union(file_names_lgr)
    #union_file_names = file_names_vector.union(file_names_fts)

    # Convert to sorted list of dicts with only fileName field
    union_items = [{'fileName': name} for name in sorted(union_file_names)]

    return union_items
    
async def run_evaluation(question_index, container_name, embedding_model, only_vector=False, only_fts=False, use_lgr=False):
    #question_index = 4
    print(f"Question: {questions_with_topk[question_index]['question']}")
    

    # Flatten multi-line entries (like Janet_My_Mother_and_Me.csv)
    from itertools import groupby

 
    #search_query = "teenaged computer hacker"
    search_query = questions_with_topk[question_index]["question"]
    #embedding_result = await openai_helper.generate_embeddings([search_query], model="text-embedding-ada-002")
    #search_query_embedded = embedding_result[0].embedding
    #search_query_arr = search_query.split(" ")

    #items_vector = get_vector_search_results(container, search_query_embedded, top_k=155, threshold=0.8)
    #items_fts = get_fulltext_search_results(container, search_query, top_k=155)
    topk = questions_with_topk[question_index]["topk"]
    vector_task = get_vector_search_results(container_name, embedding_model, search_query, top_k=topk, threshold=0.8)
    fts_task = get_fulltext_search_results(container_name, search_query, top_k=topk)
    items_vector, items_fts = await asyncio.gather(vector_task, fts_task)


    if use_lgr:
        lgr_results = await call_lazygraph_api(search_query)
        combined_results = combine_search_results_with_lgr(items_vector, items_fts, lgr_results)
    else:
        
        if only_vector:
            combined_results = items_vector
        elif only_fts:
            combined_results = items_fts
        else:
            # Combine vector and full-text search results
            combined_results = combine_search_results(items_vector, items_fts)
            print(f"Combined results: {len(combined_results)}")
        
    return combined_results


def check_recall(question_index, combined_results):
    
    with open(os.path.join("questions", f'question{question_index + 1}.txt'), 'r', encoding='utf-8') as file:
        q1_lines = [line.strip() for line in file if line.strip()]

    q_files = []
    temp = []
    for line in q1_lines:
        temp.append(line.replace("txt", "csv"))
        if line.endswith('.txt'):
            q_files.append('_'.join(temp))
            temp = []

    q1_set = set(q_files)
    item_files_set = {item['fileName'] for item in combined_results}

    missing_in_items = q1_set - item_files_set
    extra_in_items = item_files_set - q1_set

    # print extra files in q1_set
    #print("Files in q1.txt but missing in search:")
    #for f in sorted(missing_in_items):
    #    print(f)

    print("Count of files in golden_answers but missing in search:", len(missing_in_items))

    # correct recall calculation
    recall = (len(q1_set) - len(missing_in_items)) / len(q1_set) * 100
    print(f"Recall: {recall:.2f}%")



    true_positives = q1_set & item_files_set
    false_positives = item_files_set - q1_set

    precision = len(true_positives) / len(item_files_set) * 100 if item_files_set else 0
    print(f"Precision: {precision:.2f}%")

    if precision + recall > 0:
        f1_score = 2 * (precision * recall) / (precision + recall)
        print(f"F1 Score: {f1_score:.2f}%")
    else:
        print("F1 Score: Undefined (no precision or recall)")

    #print("Files in q1.txt but missing in search:")
    #for f in sorted(missing_in_items):
    #    print(f)

# %% [markdown]
# ### Vector Query with Filter

# %%
container_name = "books_perftest" 
embedding_model = "text-embedding-ada-002" 
question = questions[0]
print(question)


async def get_vector_search_results_with_filter(container_name, embedding_model, search_query, top_k=5, threshold=0.7):
    embedding_result = await openai_helper.get_embeddings([search_query], model=embedding_model)
    search_query_embedded = embedding_result # embedding_result[0].embedding
    def run_query():
        
        container = database.get_container_client(container_name)    
        items = container.query_items( 
            query="""
            SELECT top @top_k c.fileName, VectorDistance(c.textVector, @embedding) AS textSimilarityScore 
            FROM c
            WHERE VectorDistance(c.textVector, @embedding) > @threshold
            AND 
            CONTAINS(c.fileName, "New")
            AND 
            c.fileName = 'book_New_York_2000.csv'
            ORDER BY VectorDistance(c.textVector, @embedding) 
            """, 
            parameters=[
                {"name": "@embedding", "value": search_query_embedded},
                {"name": "@top_k", "value": top_k},
                {"name": "@threshold", "value": threshold}
            ], 
            enable_cross_partition_query=True)
        return [item for item in items]

    return await asyncio.to_thread(run_query)
items = await get_vector_search_results_with_filter(container_name, embedding_model, question, top_k=5, threshold=0.7)

for item in items:
    print(item)
    #print(item['fileName'])
    #query_with_filename(item['fileName'])
    #print(item['textSimilarityScore'])
    #print("***************")
# Out:
# Give me a list of books published in the year 2000
# {'fileName': 'book_New_York_2000.csv', 'textSimilarityScore': 0.8291248783696955}

# %% [markdown]
# #### using text-embedding-ada-002 1536 dimensions
#
# #### Combine Vector Search and Full Text Search

# %%
container_name = "books002" # text-embedding-ada-002
embedding_model = "text-embedding-ada-002" # text-embedding-ada-002

range_limit = 1 # len(questions) 1 to 9

async def run_all_evaluations(only_vector=False, only_fts=False, use_lgr=False):
    tasks = [run_evaluation(i, container_name, embedding_model, only_vector=only_vector, only_fts=only_fts, use_lgr=use_lgr) for i in range(range_limit)]
    results = await asyncio.gather(*tasks)

    for i, (combined_results) in enumerate(results):
        print(f"\n=== Evaluation for Question {i} ===")
        print(f"Question: {questions[i]}")
        check_recall(i,combined_results)



# Needed only once in a Jupyter session
nest_asyncio.apply()

await run_all_evaluations(use_lgr=False)
# Out:
# Question: Give me a list of books published in the year 2000
# Combined results: 382
#
# === Evaluation for Question 0 ===
# Question: Give me a list of books published in the year 2000
# Count of files in golden_answers but missing in search: 92
# Recall: 71.78%
# Precision: 61.26%
# F1 Score: 66.10%

# %% [markdown]
# ### Full Text Search

# %%
container_name = "books_perftest" 
embedding_model = "text-embedding-ada-002" 
question = questions[0]
print(question)

async def full_text_search(container_name, search_query, top_k=5):
    def run_query():
        try:
            container = database.get_container_client(container_name)
            search_query_arr = search_query.split(" ")
            #print(search_query_arr)
            query_string = f"""
            SELECT TOP @top_k c.fileName
            FROM c
            ORDER BY RANK FullTextScore(c.text, {search_query_arr})
            """

            items = container.query_items(
                query=query_string,
                parameters=[
                    {"name": "@top_k", "value": top_k},
                ],
                enable_cross_partition_query=True
            )
            return [item for item in items]
        except Exception as e:
            print(f"Error in query: {e}")
            return []

    return await asyncio.to_thread(run_query)

items = await full_text_search(container_name, question, top_k=5)

for item in items:
    print(item)
    #print(item['fileName'])
    #query_with_filename(item['fileName'])
    #print(item['textSimilarityScore'])
    #print("***************")
# Out:
# Give me a list of books published in the year 2000
# {'fileName': 'book_Juiced.csv'}
# {'fileName': 'haunted_North_shore_Northside.csv'}
# {'fileName': 'book_Witch_Grass.csv'}
# {'fileName': 'haunted_NE_Center_St..csv'}
# {'fileName': 'haunted_Old_Earth_Island_Manufacturing_Facility.csv'}

# %% [markdown]
# #### RRF Query

# %%
container_name = "books_perftest" 
embedding_model = "text-embedding-ada-002" 
question = questions[0]
print(question)

async def search_with_rrf(container_name, embedding_model, search_query, top_k=5, threshold=0.7):
    embedding_result = await openai_helper.get_embeddings([search_query], model=embedding_model)
    search_query_embedded = embedding_result  # already a list of floats
    keywords = ' '.join(f'"{word}"' for word in search_query.split())
    def run_query():
        try:
            container = database.get_container_client(container_name)
            search_query_arr = search_query.split(" ") #['published', 'in', 'the', 'year', '2000']
            items = container.query_items(
                query=f"""
                SELECT TOP {top_k} c.fileName, c.text
                FROM c
                ORDER BY RANK RRF(
                    FullTextScore(c.text, {search_query_arr}),
                    VectorDistance(c.textVector, {search_query_embedded})
                )
                """,
                parameters=[],
                enable_cross_partition_query=True
            )
            return [item for item in items]
        except Exception as e:
            print(f"Error in query: {e}")
            return []

    return await asyncio.to_thread(run_query)

items = await search_with_rrf(container_name, embedding_model, question, top_k=5, threshold=0.7)

for item in items:
    print(item)
    #print(item['fileName'])
    #query_with_filename(item['fileName'])
    #print(item['textSimilarityScore'])
    #print("***************")
# Out:
# Give me a list of books published in the year 2000
# {'fileName': 'book_New_York_2000.csv', 'text': 'ISBN-13: 9781580931779.\nISBN-10: 1580931774.\nTitle: New York 2000.\nSubtitle: Architecture and Urbanism Between the Bicentennial and the Millennium.\nAuthors: Robert A. M. Stern;David Fishman;Jacob Tilove.\nCategories: Architecture.\nThumbnail: http://books.google.com/books/content?id=F2xyQgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api.\nDescription: "Featuring insightful discussions on the development of Battery Park City, the rebirth of Harlem and Times Square, the creation of the cultural precinct around the new MoMA, and the reclaiming of the waterfront along the East and Hudson Rivers as recreational parkland, New York 2000 documents ongoing commitments to innovation and renovation and celebrates the achievements of internationally recognized architects, including Sir Norman Foster, Cesar Pelli, Richard Meier, and Renzo Piano." "The survey of organized geographically, beginning in Lower Manhattan and moving north through Harlem and to the outer boroughs including the Bronx, Queens, Brooklyn, and Staten Island. Woven throughout is commentary on the repercussions of September 11, 2001, New York 2000 is a thorough study of how a world-class metropolis preserves, showcases, and constructs an architectural heritage that endures over the course of two centuries."--BOOK JACKET..\nPublished Year: 2006.\nAverage Rating: 4.47.\nNumber of Pages: 1520.\nRatings Count: 15.\n'}
# {'fileName': 'book_The_Science_Book.csv', 'text': 'ISBN-13: 9781841882543.\nISBN-10: 1841882542.\nTitle: The Science Book.\nSubtitle: .\nAuthors: Peter Tallack.\nCategories: Science.\nThumbnail: http://books.google.com/books/content?id=iw73HE2cmRkC&printsec=frontcover&img=1&zoom=1&source=gbs_api.\nDescription: This chronology of scientific discoveries and achievements spans from 35,000 BC ("Origins of counting") to 2000 ("Human genome sequence)..\nPublished Year: 2006.\nAverage Rating: 4.05.\nNumber of Pages: 528.\nRatings Count: 23.\n'}
# {'fileName': 'book_My_Century.csv', 'text': 'ISBN-13: 9780571203123.\nISBN-10: 0571203124.\nTitle: My Century.\nSubtitle: .\nAuthors: Günter Grass.\nCategories: History, Modern.\nThumbnail: http://books.google.com/books/content?id=5MOAPwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api.\nDescription: Here, Gunter Grass writes of great events and seemingly trivial ones, of technical developments and scientific discoveries, of achievements in culture, sport, of megolamania, persecution and murder, war and disasters and of new beginnnings..\nPublished Year: 2000.\nAverage Rating: 3.45.\nNumber of Pages: 248.\nRatings Count: 775.\n'}
# {'fileName': 'book_The_Best_American_Travel_Writing_2006.csv', 'text': 'ISBN-13: 9780618582150.\nISBN-10: 0618582150.\nTitle: The Best American Travel Writing 2006.\nSubtitle: .\nAuthors: Tim Cahill;Jason Wilson.\nCategories: Travel.\nThumbnail: http://books.google.com/books/content?id=H8GRNgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api.\nDescription: Presents an anthology of the best travel writing published in the previous year, selected from magazines, newspapers, and web sites..\nPublished Year: 2006.\nAverage Rating: 3.93.\nNumber of Pages: 352.\nRatings Count: 488.\n'}
# {'fileName': 'book_The_Best_American_Mystery_Stories_2004.csv', 'text': 'ISBN-13: 9780618329670.\nISBN-10: 0618329676.\nTitle: The Best American Mystery Stories 2004.\nSubtitle: .\nAuthors: Nelson DeMille;Otto Penzler.\nCategories: Fiction.\nThumbnail: http://books.google.com/books/content?id=WeSBCKu7Cd8C&printsec=frontcover&img=1&zoom=1&source=gbs_api.\nDescription: Presents a collection of mystery stories selected from magazines in the United States and Canada.\nPublished Year: 2004.\nAverage Rating: 3.53.\nNumber of Pages: 448.\nRatings Count: 95.\n'}

# %%
questions[3]
# Out:
# 'Give me some haunted incidents from california state'

# %%
container_name = "books002" 
embedding_model = "text-embedding-ada-002" # text-embedding-ada-002
top_k = 5
threshold = 0.7
search_query = questions[3]
embedding_result = await openai_helper.generate_embeddings([search_query], model=embedding_model)
search_query_embedded = embedding_result[0].embedding


container = database.get_container_client(container_name)    
items = container.query_items( 
    query="""
    SELECT top @top_k c.fileName, VectorDistance(c.textVector, @embedding) AS textSimilarityScore 
    FROM c
    WHERE VectorDistance(c.textVector, @embedding) > @threshold
    ORDER BY VectorDistance(c.textVector, @embedding) 
    """, 
    parameters=[
        {"name": "@embedding", "value": search_query_embedded},
        {"name": "@top_k", "value": top_k},
        {"name": "@threshold", "value": threshold}
    ], 
    enable_cross_partition_query=True)

for item in items:
    print(item)
# Out:
# azure openai endpoint:https://aihub6750316290.openai.azure.com/
# {'fileName': 'haunted_Old_Camarillo_State_Hospital.csv', 'textSimilarityScore': 0.8246408552210656}
# {'fileName': 'haunted_Sun_Microsystems.csv', 'textSimilarityScore': 0.8239575781149956}
# {'fileName': 'haunted_old_stage_road.csv', 'textSimilarityScore': 0.8232585069424947}
# {'fileName': 'haunted_Haunted_Mansion.csv', 'textSimilarityScore': 0.820248466272007}
# {'fileName': 'haunted_Los_Angeles_City_Hall.csv', 'textSimilarityScore': 0.8193282542837594}

# %%
container_name = "books_small" 
embedding_model = "text-embedding-3-small" # text-embedding-ada-002
combined_results, q1_files =  await run_evaluation([questions[3]],container_name, embedding_model)
#check_recall(q1_files, combined_results)

# %%
combined_results, q1_files =  await run_evaluation(8)
check_recall(q1_files, combined_results)

# %%
combined_results, q1_files =  await run_evaluation(5)
check_recall(q1_files, combined_results)
# Out:
# Question: Give me wines tasted by Roger Voss
# embedding model: text-embedding-ada-002
# ['Give', 'me', 'wines', 'tasted', 'by', 'Roger', 'Voss']
# Count of files in q1.txt but missing in search: 81
# Recall: 17.35%
# Files in q1.txt but missing in search:
# wine_A._Margaine_NV_Le_Brut_Premier_Cru__(Champagne).csv
# wine_Alphonse_Mellot_2014_Génération_Dix-Neuf__(Sancerre).csv
# wine_Armand_de_Brignac_NV_Blanc_de_Blancs_Brut_Chardonnay_(Champagne).csv
# wine_Cartuxa_2011_Pêra-Manca_Red_(Alentejo).csv
# wine_Casa_Ferreirinha_2004_Barca_Velha_Red_(Douro).csv
# wine_Casa_Ferreirinha_2007_Reserva_Especial_Red_(Douro).csv
# wine_Casa_Ferreirinha_2008_Barca-Velha_Red_(Douro).csv
# wine_Castello_Banfi_1997__Brunello_di_Montalcino.csv
# wine_Château_Beauséjour_2012__Puisseguin_Saint-Émilion.csv
# wine_Château_Bellevue_la_Forêt_2012_Red_(Fronton).csv
# wine_Château_Beychevelle_2014_Amiral_de_Beychevelle__(Saint-Julien).csv
# wine_Château_Bouscaut_2013__Pessac-Léognan.csv
# wine_Château_Bréhat_2013__Castillon_Côtes_de_Bordeaux.csv
# wine_Château_Carbonnieux_2013__Pessac-Léognan.csv
# wine_Château_Couhins_2013__Pessac-Léognan.csv
# wine_Château_Coussin_2014_Cuvée_César_à_Sumeire_Rosé_(Côtes_de_Provence_Sainte-Victoire).csv
# wine_Château_Fonbadet_2014__Pauillac.csv
# wine_Château_Guibeau_2014__Castillon_Côtes_de_Bordeaux.csv
# wine_Château_Haut-Bacalan_2013__Pessac-Léognan.csv
# wine_Château_Haut-Bailly_2013__Pessac-Léognan.csv
# wine_Château_Haut-Brion_2013__Pessac-Léognan.csv
# wine_Château_La_Mission_Haut-Brion_2000_Pessac-Lï¿½ognan__(Bordeaux).csv
# wine_Château_Labastide_Orliac_2008_1780_Royal_Heritage_Red_(Brulhois).csv
# wine_Château_Lacaussade-Saint-Martin_2014__Blaye_Côtes_de_Bordeaux.csv
# wine_Château_Lagrézette_2014_Cuvée_Marguerite_Massaut_Malbec_(Cahors).csv
# wine_Château_Lamartine_2011_Cuvée_Particulière_Malbec-Tannat_(Cahors).csv
# wine_Château_Lamartine_2012_Cuvée_Particulière_Malbec-Tannat_(Cahors).csv
# wine_Château_Peyros_2009_Cuvée_Greenwich_Tannat_(Madiran).csv
# wine_Château_Pichon_Longueville_2012_Les_Griffons_de_Pichon_Baron__(Pauillac).csv
# wine_Château_Puyanché_2014__Francs_Côtes_de_Bordeaux.csv
# wine_Château_Saint-Maur_2015_Clos_de_Capelune_Rosé_(Côtes_de_Provence).csv
# wine_Château_de_Fieuzal_2013__Pessac-Léognan.csv
# wine_Château_de_Rouillac_2013__Pessac-Léognan.csv
# wine_Château_du_Cros_2012__Cadillac_Côtes_de_Bordeaux.csv
# wine_Château_la_Brande_2014__Castillon_Côtes_de_Bordeaux.csv
# wine_Château_la_Freynelle_2015__Bordeaux_Blanc.csv
# wine_Clau_de_Nell_2014_Grolleau_(Val_de_Loire).csv
# wine_Clos_Puy_Arnaud_2012__Castillon_Côtes_de_Bordeaux.csv
# wine_Conceito_Vinhos_2015_Unico_Red_(Douro).csv
# wine_Dautel-Cadot_NV_Cuvée_Prestige_Brut__(Champagne).csv
# wine_Delas_Frères_1999_Les_Bessards__(Hermitage).csv
# wine_Domaine_Coustarret_2012_Le_Barou__(Jurançon).csv
# wine_Domaine_Vacheron_2014_L'Enclos_des_Remparts_Sauvignon_Blanc_(Vin_de_France).csv
# wine_Domaine_de_Cause_2010_Notre_Dame_des_Champs_Malbec_(Cahors).csv
# wine_Domaine_de_Cause_2011_Notre_Dame_des_Champs_Malbec_(Cahors).csv
# wine_Domaine_de_Savagny_NV_Macvin_du_Jura_White_(Côtes_du_Jura).csv
# wine_Domaine_de_l'A_2012__Castillon_Côtes_de_Bordeaux.csv
# wine_Domaine_de_la_Tour_du_Bief_2010__Moulin-à-Vent.csv
# wine_Domaine_du_Comte_Liger-Belair_2010__La_Romanée.csv
# wine_Domaine_du_Moulin_2013_Florentin_Braucol_(Gaillac).csv
# wine_Domaines_Devillard_2014_Château_de_Chamirey_Les_Cinq__(Mercurey).csv
# wine_E._Guigal_1999_Lieu-dit_Saint-Joseph__(Saint-Joseph).csv
# wine_Fanti_1997__Brunello_di_Montalcino.csv
# wine_J.L._Chave_1999__Hermitage.csv
# wine_Jean-Luc_Baldès_2012_Clos_Triguedina_The_New_Black_Wine__Malbec_(Cahors).csv
# wine_Jean-Luc_Baldès_2013_Clos_Triguedina_The_New_Black_Wine_Malbec_(Cahors).csv
# wine_La_Chablisienne_2014_Château_Grenouilles_Grand_Cru__(Chablis).csv
# wine_M._Chapoutier_1999_Le_Méal_Ermitage__(Hermitage).csv
# wine_Moët_&_Chandon_2003_Vintage_Brut__(Champagne).csv
# wine_Mouchão_2012_Red_(Alentejo).csv
# wine_Paul_Jaboulet_Aîné_1999_La_Chapelle__(Hermitage).csv
# wine_Pierre_Gerbais_NV_L'Originale_Extra_Brut_Pinot_Blanc_(Champagne).csv
# wine_Prats_&_Symington_LDA_2011_Chryseia_Red_(Douro).csv
# wine_Quinta_de_Chocapalha_2011_CH_by_Chocapalha_Touriga_Nacional_(Lisboa).csv
# wine_Quinta_do_Monte_Xisto_2013_Red_(Douro).csv
# wine_Quinta_do_Mourão_NV_10-Years-Old_Tawny_Unreported__(Port).csv
# wine_Quinta_do_Noval_2013_Vintage__(Port).csv
# wine_Quinta_do_Noval_2015_Vintage__(Port).csv
# wine_Quinta_do_Perdigão_2011_Alfrocheiro_(Dão).csv
# wine_Quinta_do_Pôpa_2013_Pôpa_VV_Vinhas_Velhas_Red_(Douro).csv
# wine_Quinta_do_Pôpa_2014_Pôpa_Black_Edition_Red_(Douro).csv
# wine_Quinta_do_Sobral_2014_Vinha_da_Neta_Red_(Dão).csv
# wine_Quinta_do_Vale_Meão_2005_Red_(Douro).csv
# wine_Quinta_do_Vale_Meão_2013_Vintage__(Port).csv
# wine_Quinta_do_Vale_Meão_2014_Red_(Douro).csv
# wine_Salon_2004_Le_Mesnil_Blanc_de_Blancs_Brut_Chardonnay_(Champagne).csv
# wine_Talenti_1997__Brunello_di_Montalcino.csv
# wine_Vollereaux_NV_Brut_Rosé_de_Saignée_Pinot_Noir_(Champagne).csv
# wine_Wine_&_Soul_2012_Manoella_Red_(Douro).csv
# wine_Wine_&_Soul_2012_Pintas_Red_(Douro).csv
# wine_Wine_&_Soul_2013_Quinta_da_Manoella_VV_Red_(Douro).csv

# %%
embedding_result = await openai_helper.generate_embeddings([questions[0]], model=embedding_model)
search_query_embedded = embedding_result[0].embedding
container_name = "books002" 
embedding_model = "text-embedding-ada-002" # text-embedding-ada-002
items_vector = await get_vector_search_results(container_name,embedding_model, questions[0], top_k=400, threshold=0.6)
print(f"Total items found: {len(items_vector)}")
for item in items_vector:
    print(item)
# Out:
# azure openai endpoint:https://aihub6750316290.openai.azure.com/
# azure openai endpoint:https://aihub6750316290.openai.azure.com/
# Total items found: 400
# {'fileName': 'book_New_York_2000.csv', 'textSimilarityScore': 0.8291248783696955}
# {'fileName': 'book_The_Best_American_Mystery_Stories_2004.csv', 'textSimilarityScore': 0.8281981356883056}
# {'fileName': 'book_The_Best_American_Travel_Writing_2006.csv', 'textSimilarityScore': 0.8236891674129334}
# {'fileName': 'book_The_Best_American_Science_Writing_2002.csv', 'textSimilarityScore': 0.823666388900886}
# {'fileName': 'book_My_Century.csv', 'textSimilarityScore': 0.8235646759203652}
# {'fileName': 'book_The_Science_Book.csv', 'textSimilarityScore': 0.8223925593132668}
# {'fileName': 'book_Ten_Great_Works_of_Philosophy.csv', 'textSimilarityScore': 0.8214092618962769}
# {'fileName': 'book_The_Best_American_Sports_Writing_2003.csv', 'textSimilarityScore': 0.8202521211021323}
# {'fileName': 'book_The_Best_American_Crime_Writing_2006.csv', 'textSimilarityScore': 0.8193680698975054}
# {'fileName': 'book_The_Best_American_Sports_Writing_2006.csv', 'textSimilarityScore': 0.8187352835854796}
# {'fileName': 'book_Modern_Classics_of_Science_Fiction.csv', 'textSimilarityScore': 0.8166199837304231}
# {'fileName': 'book_Out_of_this_World.csv', 'textSimilarityScore': 0.815259455496175}
# {'fileName': 'book_The_O._Henry_Prize_Stories_2003.csv', 'textSimilarityScore': 0.8147100664174062}
# {'fileName': 'book_Old_Twentieth.csv', 'textSimilarityScore': 0.8127707069366427}
# {'fileName': 'book_American_writers.csv', 'textSimilarityScore': 0.8123144874312943}
# {'fileName': 'book_A_New_Collection_of_Three_Complete_Novels.csv', 'textSimilarityScore': 0.8112341500144923}
# {'fileName': 'news_Richard_and_Judy_choose_top_books.csv', 'textSimilarityScore': 0.8111371860769273}
# {'fileName': 'book_Best_of_the_Eighties.csv', 'textSimilarityScore': 0.8103713112206193}
# {'fileName': 'book_The_Best_of_Young_British_Novelists.csv', 'textSimilarityScore': 0.810222267817911}
# {'fileName': 'book_75_Years_of_Little_Golden_Books__1942-2017.csv', 'textSimilarityScore': 0.809014021328616}
# {'fileName': 'book_The_Best_of_Tales.csv', 'textSimilarityScore': 0.8088048267122495}
# {'fileName': 'book_Pieces.csv', 'textSimilarityScore': 0.8081556694745903}
# {'fileName': 'book_Novels,_1901-1902.csv', 'textSimilarityScore': 0.8072448643361562}
# {'fileName': 'book_100_Great_Fantasy_Short_Short_Stories.csv', 'textSimilarityScore': 0.8072389574666098}
# {'fileName': 'book_1968.csv', 'textSimilarityScore': 0.8070506581474083}
# {'fileName': 'book_Mémoires,_Plaidoiries_Et_Documents.csv', 'textSimilarityScore': 0.8068695295740277}
# {'fileName': 'book_The_best_of_Philip_K._Dick.csv', 'textSimilarityScore': 0.8066569431137665}
# {'fileName': 'book_Monte_Cooks_Years_Best_D20_04.csv', 'textSimilarityScore': 0.8064803596465164}
# {'fileName': 'book_1,000_Places_to_See_Before_You_Die.csv', 'textSimilarityScore': 0.805997823802323}
# {'fileName': 'book_Marvel_1602.csv', 'textSimilarityScore': 0.8059030413529354}
# {'fileName': 'book_The_Sixties.csv', 'textSimilarityScore': 0.8058485370114442}
# {'fileName': 'book_Novels_1957-1962.csv', 'textSimilarityScore': 0.8055156505625026}
# {'fileName': 'book_The_Best_American_Spiritual_Writing_2006.csv', 'textSimilarityScore': 0.8053834931054696}
# {'fileName': 'book_Best_Stories.csv', 'textSimilarityScore': 0.8052956904645107}
# {'fileName': 'book_Gothic!.csv', 'textSimilarityScore': 0.80514184742664}
# {'fileName': "book_The_Children's_Book_of_America.csv", 'textSimilarityScore': 0.8050702945461801}
# {'fileName': 'book_Thriller.csv', 'textSimilarityScore': 0.8048989855132422}
# {'fileName': 'book_The_Complete_Short_Prose,_1929-1989.csv', 'textSimilarityScore': 0.8042428571515898}
# {'fileName': 'book_Blue_World.csv', 'textSimilarityScore': 0.8038370330911676}
# {'fileName': 'book_Firebirds.csv', 'textSimilarityScore': 0.8038266067686843}
# {'fileName': 'book_Selected_Stories.csv', 'textSimilarityScore': 0.8037402780487104}
# {'fileName': 'book_Stephen_King_Omnibus.csv', 'textSimilarityScore': 0.803732315597359}
# {'fileName': 'book_Crime_Novels.csv', 'textSimilarityScore': 0.8034617589383776}
# {'fileName': 'book_The_Roald_Dahl_Treasury.csv', 'textSimilarityScore': 0.8029861723628358}
# {'fileName': 'book_Collected_Fictions.csv', 'textSimilarityScore': 0.802959643044912}
# {'fileName': "book_JK_Rowling's_Harry_Potter_Novels.csv", 'textSimilarityScore': 0.8027515401417702}
# {'fileName': 'book_Six_Memos_for_the_Next_Millennium.csv', 'textSimilarityScore': 0.802749200794791}
# {'fileName': 'book_Three_Terrifying_Bestselling_Novels.csv', 'textSimilarityScore': 0.8026758864863571}
# {'fileName': 'book_The_Books_of_Magic.csv', 'textSimilarityScore': 0.8024930158905954}
# {'fileName': 'book_The_Best_of_H.P._Lovecraft.csv', 'textSimilarityScore': 0.8023103558024479}
# {'fileName': 'book_The_Complete_Stories_of_Truman_Capote.csv', 'textSimilarityScore': 0.8019353392623175}
# {'fileName': 'book_The_Stories_of_John_Cheever.csv', 'textSimilarityScore': 0.8016830990200053}
# {'fileName': 'book_The_Mammoth_Book_of_Golden_Age_Science_Fiction.csv', 'textSimilarityScore': 0.8016724336228105}
# {'fileName': 'book_Where_We_Are,_what_We_See.csv', 'textSimilarityScore': 0.8014385164361179}
# {'fileName': 'book_Breath,_Eyes,_Memory.csv', 'textSimilarityScore': 0.8014011975877549}
# {'fileName': 'book_Interfictions.csv', 'textSimilarityScore': 0.8013983967701739}
# {'fileName': 'book_Every_Book_Its_Reader.csv', 'textSimilarityScore': 0.8006878658994722}
# {'fileName': 'book_Best_Science_Fiction_Stories_of_H._G._Wells.csv', 'textSimilarityScore': 0.8006222471558312}
# {'fileName': 'book_Novels,_1896-1899.csv', 'textSimilarityScore': 0.8003286893449764}
# {'fileName': 'book_New_Amazons.csv', 'textSimilarityScore': 0.8001798057658261}
# {'fileName': 'book_Dealing_in_Futures.csv', 'textSimilarityScore': 0.8001477523267174}
# {'fileName': 'book_Duel.csv', 'textSimilarityScore': 0.8000549526078574}
# {'fileName': 'book_Wild_Fire.csv', 'textSimilarityScore': 0.7998746799986717}
# {'fileName': 'book_Koko.csv', 'textSimilarityScore': 0.7995038413147602}
# {'fileName': 'book_H.G._Wells_Science_Fiction_Treasury.csv', 'textSimilarityScore': 0.7994605058028798}
# {'fileName': 'book_Matters_of_Choice.csv', 'textSimilarityScore': 0.7993959522751116}
# {'fileName': 'book_Mao_II.csv', 'textSimilarityScore': 0.799228566235648}
# {'fileName': 'book_All_the_Names.csv', 'textSimilarityScore': 0.7992001712834451}
# {'fileName': 'book_Fear_Nothing.csv', 'textSimilarityScore': 0.799061195562016}
# {'fileName': 'book_Writing_with_Intent.csv', 'textSimilarityScore': 0.7990596517772529}
# {'fileName': 'book_V..csv', 'textSimilarityScore': 0.7988824885537436}
# {'fileName': 'book_The_Campfire_Collection.csv', 'textSimilarityScore': 0.7987901496118516}
# {'fileName': "book_If_You_Don't_Know_by_Now.csv", 'textSimilarityScore': 0.7987577916340776}
# {'fileName': 'book_That_was_Then,_this_is_Now.csv', 'textSimilarityScore': 0.7986131785885734}
# {'fileName': 'book_Double_Fold.csv', 'textSimilarityScore': 0.7985112196598145}
# {'fileName': 'book_Killobyte.csv', 'textSimilarityScore': 0.7984045340443655}
# {'fileName': 'book_The_Best_of_Wodehouse.csv', 'textSimilarityScore': 0.7983513276666068}
# {'fileName': 'book_Clive_Cussler_and_Dirk_Pitt_Revealed.csv', 'textSimilarityScore': 0.7983144240374634}
# {'fileName': 'book_BFF.csv', 'textSimilarityScore': 0.7982973619364253}
# {'fileName': 'book_Travels_in_Hyper_Reality.csv', 'textSimilarityScore': 0.7982352157164977}
# {'fileName': 'book_The_World_Treasury_of_Physics,_Astronomy,_and_Mathematics.csv', 'textSimilarityScore': 0.7981523100406465}
# {'fileName': 'book_Four_Novels.csv', 'textSimilarityScore': 0.797918696838325}
# {'fileName': 'book_The_Portable_Arthur_Miller.csv', 'textSimilarityScore': 0.7979007654516707}
# {'fileName': 'book_Mission_of_Honor.csv', 'textSimilarityScore': 0.7978814101758008}
# {'fileName': 'book_Poems,_New_and_Collected,_1957-1997.csv', 'textSimilarityScore': 0.7978251855138838}
# {'fileName': 'book_Things.csv', 'textSimilarityScore': 0.7977520042974248}
# {'fileName': 'book_Everything_and_Nothing.csv', 'textSimilarityScore': 0.7973380740317119}
# {'fileName': 'book_The_Transition_of_H.P._Lovecraft.csv', 'textSimilarityScore': 0.7973226328094924}
# {'fileName': 'book_A_Tolkien_Miscellany.csv', 'textSimilarityScore': 0.7973160480279076}
# {'fileName': 'book_Story_of_Philosophy.csv', 'textSimilarityScore': 0.7971543545878702}
# {'fileName': 'book_Oryx_and_Crake.csv', 'textSimilarityScore': 0.7970932608534791}
# {'fileName': 'book_Scary_stories_3.csv', 'textSimilarityScore': 0.7970389381705795}
# {'fileName': 'book_The_Best_of_Roald_Dahl.csv', 'textSimilarityScore': 0.7970118890282822}
# {'fileName': 'book_The_Search_for_Power.csv', 'textSimilarityScore': 0.7968719040727051}
# {'fileName': 'news_Spark_heads_world_Booker_list.csv', 'textSimilarityScore': 0.7968555181861742}
# {'fileName': 'book_Best_Science_Fiction_Stories_of_Clifford_D._Simak.csv', 'textSimilarityScore': 0.79670603773033}
# {'fileName': 'book_Man_and_Boy.csv', 'textSimilarityScore': 0.7965516292169735}
# {'fileName': 'book_What_are_the_7_Wonders_of_the_World_.csv', 'textSimilarityScore': 0.7963591890467122}
# {'fileName': "book_If_on_a_Winter's_Night_a_Traveler.csv", 'textSimilarityScore': 0.7963351931377333}
# {'fileName': 'book_Classic_Myths_to_Read_Aloud__The_Great_Stories_of_Greek_and_Roman_Mythology,_Specially_Arranged_for_Children_Five_and_Up_by_an_Educational_Expert.csv', 'textSimilarityScore': 0.7963284011809787}
# {'fileName': 'book_Three_Graphic_Novels.csv', 'textSimilarityScore': 0.7963043420883473}
# {'fileName': 'book_Toni_Morrison.csv', 'textSimilarityScore': 0.7962171723146286}
# {'fileName': 'book_Nineteen_Nineteen.csv', 'textSimilarityScore': 0.7961180399468298}
# {'fileName': 'book_Fairy_Tales.csv', 'textSimilarityScore': 0.7961041204796625}
# {'fileName': "book_Don't_Know_Much_about_American_History.csv", 'textSimilarityScore': 0.7959677231057585}
# {'fileName': 'book_Code_Orange.csv', 'textSimilarityScore': 0.7956100193643267}
# {'fileName': 'book_Random_House_Crossword_Megaomnibus.csv', 'textSimilarityScore': 0.7955672337815637}
# {'fileName': 'book_The_New_York_Times_Guide_to_Essential_Knowledge.csv', 'textSimilarityScore': 0.7955180549737184}
# {'fileName': 'book_Nineteen_Sixty_Eight.csv', 'textSimilarityScore': 0.7955131054300894}
# {'fileName': 'book_Complete_Stories,_1892-1898.csv', 'textSimilarityScore': 0.7954993467831644}
# {'fileName': 'book_The_Christmas_Shoes.csv', 'textSimilarityScore': 0.7954637044646863}
# {'fileName': "book_McSweeney's.csv", 'textSimilarityScore': 0.7952228157623841}
# {'fileName': 'book_More_Twisted.csv', 'textSimilarityScore': 0.7950245182046977}
# {'fileName': 'book_Animal.csv', 'textSimilarityScore': 0.7948279672899644}
# {'fileName': 'book_The_Bookseller_of_Kabul.csv', 'textSimilarityScore': 0.7946775636275837}
# {'fileName': 'book_Snow_Crash.csv', 'textSimilarityScore': 0.7946049234064052}
# {'fileName': 'book_The_Percy_Jackson_and_the_Olympians,_Book_Two__Sea_of_Monsters.csv', 'textSimilarityScore': 0.7945968216943996}
# {'fileName': 'book_Sammlung.csv', 'textSimilarityScore': 0.7945738907003902}
# {'fileName': 'book_Tell_Me_No_Lies.csv', 'textSimilarityScore': 0.794560440098944}
# {'fileName': 'book_Memoirs_of_the_Second_World_War.csv', 'textSimilarityScore': 0.7945530197627846}
# {'fileName': 'book_Two_Complete_Novels.csv', 'textSimilarityScore': 0.794547685990735}
# {'fileName': 'book_The_Norton_Anthology_of_Literature_by_Women.csv', 'textSimilarityScore': 0.7945369274445653}
# {'fileName': 'book_Eaters_of_the_Dead.csv', 'textSimilarityScore': 0.7945315471204252}
# {'fileName': 'book_Dispatches.csv', 'textSimilarityScore': 0.7945314797436683}
# {'fileName': 'book_The_Norton_Anthology_of_Short_Fiction.csv', 'textSimilarityScore': 0.7944822755056129}
# {'fileName': "book_'I'm_Telling_You_Stories'.csv", 'textSimilarityScore': 0.7944356248894302}
# {'fileName': 'book_A_Thousand_Orange_Trees.csv', 'textSimilarityScore': 0.7944325536605682}
# {'fileName': 'book_The_Harry_Potter_Collection.csv', 'textSimilarityScore': 0.7944287953382727}
# {'fileName': 'book_Complete_Works.csv', 'textSimilarityScore': 0.794375196141693}
# {'fileName': 'book_The_Pleasure_of_Finding_Things_Out.csv', 'textSimilarityScore': 0.7943220758984338}
# {'fileName': 'book_The_Paris_Review_Interviews,_I.csv', 'textSimilarityScore': 0.7942946473704233}
# {'fileName': 'book_Harry_Potter.csv', 'textSimilarityScore': 0.7942857054632241}
# {'fileName': 'book_Great_Short_Stories_by_American_Women.csv', 'textSimilarityScore': 0.7941659891689195}
# {'fileName': 'book_Morgawr.csv', 'textSimilarityScore': 0.7940806838302199}
# {'fileName': 'news_The_gaming_world_in_2005.csv', 'textSimilarityScore': 0.7940196030504558}
# {'fileName': 'book_The_Classical_World.csv', 'textSimilarityScore': 0.7939974755470153}
# {'fileName': 'book_Passage.csv', 'textSimilarityScore': 0.7939875190242432}
# {'fileName': 'book_Zombie.csv', 'textSimilarityScore': 0.7939754263380618}
# {'fileName': 'book_Kim.csv', 'textSimilarityScore': 0.7939619384337108}
# {'fileName': 'book_The_Testament.csv', 'textSimilarityScore': 0.7939429201194139}
# {'fileName': 'book_The_Fall_of_a_Sparrow.csv', 'textSimilarityScore': 0.7938705585681073}
# {'fileName': 'book_Black_Hole.csv', 'textSimilarityScore': 0.7938258733586177}
# {'fileName': 'book_The_Throne_of_the_Third_Heaven_of_the_Nations_Millennium_General_Assembly.csv', 'textSimilarityScore': 0.7938225402325615}
# {'fileName': 'book_Writings,_1902-1910.csv', 'textSimilarityScore': 0.7937999708964066}
# {'fileName': 'book_1000_Rings.csv', 'textSimilarityScore': 0.7937638605912264}
# {'fileName': 'book_X-Men.csv', 'textSimilarityScore': 0.7937440656113064}
# {'fileName': 'book_If_Tomorrow_Comes.csv', 'textSimilarityScore': 0.7937322060811338}
# {'fileName': 'book_The_One_Tree.csv', 'textSimilarityScore': 0.7937212872791348}
# {'fileName': 'book_Dragons_of_a_Vanished_Moon.csv', 'textSimilarityScore': 0.7936420326623096}
# {'fileName': 'book_Legends.csv', 'textSimilarityScore': 0.7936282732964757}
# {'fileName': 'book_Disaster!.csv', 'textSimilarityScore': 0.7936276574381783}
# {'fileName': 'book_Selected_Stories_of_H.G._Wells.csv', 'textSimilarityScore': 0.7935098639820908}
# {'fileName': 'book_The_World_and_Other_Places.csv', 'textSimilarityScore': 0.7934524897963152}
# {'fileName': 'book_Sunstorm.csv', 'textSimilarityScore': 0.7934105083509393}
# {'fileName': "book_Wolf's_Hour.csv", 'textSimilarityScore': 0.7933199896063285}
# {'fileName': 'book_Murder_in_LaMut.csv', 'textSimilarityScore': 0.7933040556630133}
# {'fileName': 'book_A_Robin_McKinley_Collection.csv', 'textSimilarityScore': 0.7932857516079543}
# {'fileName': 'book_A_Couple_of_April_Fools.csv', 'textSimilarityScore': 0.7932127786979428}
# {'fileName': 'book_Fads_and_Fallacies_in_the_Name_of_Science.csv', 'textSimilarityScore': 0.7932117563110553}
# {'fileName': 'book_The_Helene_Hanff_Omnibus.csv', 'textSimilarityScore': 0.7931387341208389}
# {'fileName': 'book_Forty_Stories.csv', 'textSimilarityScore': 0.7931367036708042}
# {'fileName': 'book_18_Best_Stories.csv', 'textSimilarityScore': 0.7931028053559485}
# {'fileName': 'book_The_Tolkien_Reader.csv', 'textSimilarityScore': 0.7930735394881807}
# {'fileName': 'book_A_History_of_the_World_in_10_1_2_Chapters.csv', 'textSimilarityScore': 0.7930596453547705}
# {'fileName': 'book_The_Letters_of_J.R.R._Tolkien.csv', 'textSimilarityScore': 0.7930366011734842}
# {'fileName': 'book_The_Novels.csv', 'textSimilarityScore': 0.793009059878404}
# {'fileName': 'book_The_Vampire_Chronicles_Collection.csv', 'textSimilarityScore': 0.7929405100575353}
# {'fileName': 'book_Chicago_Stories.csv', 'textSimilarityScore': 0.7929268099532351}
# {'fileName': 'book_The_Straight_Dope.csv', 'textSimilarityScore': 0.7928983650155513}
# {'fileName': 'book_Does_Anybody_Have_a_Problem_with_That_.csv', 'textSimilarityScore': 0.7928808990147891}
# {'fileName': 'book_Ghostwritten.csv', 'textSimilarityScore': 0.7928185366069058}
# {'fileName': "book_Winter_of_Magic's_Return.csv", 'textSimilarityScore': 0.7927802552020743}
# {'fileName': 'book_The_Complete_Novels.csv', 'textSimilarityScore': 0.7927792639569888}
# {'fileName': 'book_Amphigorey.csv', 'textSimilarityScore': 0.7926215449383333}
# {'fileName': 'book_The_New_York_Trilogy.csv', 'textSimilarityScore': 0.7926003435445752}
# {'fileName': 'book_The_Pelican_Brief.csv', 'textSimilarityScore': 0.7926001819421717}
# {'fileName': 'book_Selected_Writings.csv', 'textSimilarityScore': 0.7925936853508178}
# {'fileName': 'book_Dragon.csv', 'textSimilarityScore': 0.7925544425832006}
# {'fileName': 'book_The_Complete_Science_Fiction_Treasury_of_H.G._Wells.csv', 'textSimilarityScore': 0.7925423724386794}
# {'fileName': 'book_Blessings.csv', 'textSimilarityScore': 0.7925210707375321}
# {'fileName': 'book_Three_Early_Novels.csv', 'textSimilarityScore': 0.7924887905372536}
# {'fileName': 'book_The_Secret_Society_of_Demolition_Writers.csv', 'textSimilarityScore': 0.7924127455860274}
# {'fileName': 'book_Novels,_1936-1940.csv', 'textSimilarityScore': 0.7923913091249788}
# {'fileName': "book_Collected_Children's_Stories.csv", 'textSimilarityScore': 0.7923275456743836}
# {'fileName': 'book_Cygnet.csv', 'textSimilarityScore': 0.7922943246663037}
# {'fileName': 'book_The_Spell.csv', 'textSimilarityScore': 0.7922112043468085}
# {'fileName': 'book_Storm_of_the_century.csv', 'textSimilarityScore': 0.7921944793768725}
# {'fileName': 'book_The_Crucible_of_Time.csv', 'textSimilarityScore': 0.7921217868883256}
# {'fileName': 'book_The_Rum_Diary.csv', 'textSimilarityScore': 0.7919990956302594}
# {'fileName': 'book_X_1999,_Volume_2.csv', 'textSimilarityScore': 0.7919894370516481}
# {'fileName': 'book_Ten_Short_Stories.csv', 'textSimilarityScore': 0.7919526686412639}
# {'fileName': 'book_The_Sixteen_Pleasures.csv', 'textSimilarityScore': 0.7919090572142481}
# {'fileName': 'book_Black_Etc..csv', 'textSimilarityScore': 0.7919080843240937}
# {'fileName': 'book_William_Shakespeare__The_Complete_Works.csv', 'textSimilarityScore': 0.791898526257885}
# {'fileName': 'book_The_Collected_Stories_of_Arthur_C._Clarke.csv', 'textSimilarityScore': 0.7918780741819152}
# {'fileName': 'book_Turtles,_Termites,_and_Traffic_Jams.csv', 'textSimilarityScore': 0.7918006150047455}
# {'fileName': 'book_Complete_Poems_and_Major_Prose.csv', 'textSimilarityScore': 0.7917798398322466}
# {'fileName': 'book_The_Collected_Poems_of_Octavio_Paz,_1957-1987.csv', 'textSimilarityScore': 0.7917190901133753}
# {'fileName': 'book_Hype_and_Glory.csv', 'textSimilarityScore': 0.7916826442882899}
# {'fileName': 'book_Tales_of_the_Cthulhu_Mythos.csv', 'textSimilarityScore': 0.7916519685303387}
# {'fileName': 'book_The_Belgariad_V.2.csv', 'textSimilarityScore': 0.791609052192138}
# {'fileName': 'book_History_of_Philosophy_Volume_1.csv', 'textSimilarityScore': 0.791561662250745}
# {'fileName': 'book_The_Complete_Adventures_and_Memoirs_of_Sherlock_Holmes.csv', 'textSimilarityScore': 0.7915433792865803}
# {'fileName': "book_Richard_Brautigan's_Trout_Fishing_in_America_;_The_Pill_Versus_the_Springhill_Mine_Disaster_;_And,_In_Watermelon_Sugar.csv", 'textSimilarityScore': 0.7915365183513317}
# {'fileName': 'book_The_Oxford_Companion_to_Philosophy.csv', 'textSimilarityScore': 0.7915127829467278}
# {'fileName': 'book_Haunted.csv', 'textSimilarityScore': 0.7914964255755453}
# {'fileName': 'book_A_history_of_philosophy.csv', 'textSimilarityScore': 0.791491181406922}
# {'fileName': 'book_City_of_God.csv', 'textSimilarityScore': 0.7914653639026569}
# {'fileName': 'book_Guilty_as_Charged.csv', 'textSimilarityScore': 0.7914280351841145}
# {'fileName': 'book_Hope_is_the_Thing_with_Feathers.csv', 'textSimilarityScore': 0.7913946424560545}
# {'fileName': 'book_Amelia_Bedelia_40th_Anniversary_Collection.csv', 'textSimilarityScore': 0.7913572092932363}
# {'fileName': 'news_Cyber_crime_booms_in_2004.csv', 'textSimilarityScore': 0.7912520280969513}
# {'fileName': 'book_Complete_Poems,_1904-1962.csv', 'textSimilarityScore': 0.7912444660259421}
# {'fileName': 'book_P.S._I_Love_You.csv', 'textSimilarityScore': 0.7912135454843119}
# {'fileName': 'book_Murder_in_Foggy_Bottom.csv', 'textSimilarityScore': 0.7912076023078262}
# {'fileName': 'book_The_Hundred_Dresses.csv', 'textSimilarityScore': 0.7911733188345221}
# {'fileName': "book_The_Best_of_America's_Test_Kitchen_2007.csv", 'textSimilarityScore': 0.7910746357829943}
# {'fileName': 'book_Summer_of_Night.csv', 'textSimilarityScore': 0.7910734149128529}
# {'fileName': 'book_Journals_of_Ayn_Rand.csv', 'textSimilarityScore': 0.7910566352977004}
# {'fileName': 'book_The_Marvel_Comics_Encyclopedia.csv', 'textSimilarityScore': 0.7910079936032308}
# {'fileName': 'book_The_Humanoids.csv', 'textSimilarityScore': 0.7909767238541411}
# {'fileName': 'book_The_Tenth_Man.csv', 'textSimilarityScore': 0.7909721870291421}
# {'fileName': 'book_Anthonology.csv', 'textSimilarityScore': 0.7909540756000796}
# {'fileName': 'book_The_Partly_Cloudy_Patriot.csv', 'textSimilarityScore': 0.7909539858782122}
# {'fileName': 'book_The_Doom_that_Came_to_Sarnath.csv', 'textSimilarityScore': 0.7908820274579081}
# {'fileName': 'book_Present_Tense.csv', 'textSimilarityScore': 0.7908114649875887}
# {'fileName': 'book_Not_of_Woman_Born.csv', 'textSimilarityScore': 0.7908059064493486}
# {'fileName': 'book_Species_of_Spaces_and_Other_Pieces.csv', 'textSimilarityScore': 0.7906957262655032}
# {'fileName': 'book_My_Lord_Eternity.csv', 'textSimilarityScore': 0.7906841575588991}
# {'fileName': 'book_On_Literature.csv', 'textSimilarityScore': 0.7906631901018255}
# {'fileName': 'book_Dragondrums.csv', 'textSimilarityScore': 0.7905124137850732}
# {'fileName': 'book_Doom_of_the_Darksword.csv', 'textSimilarityScore': 0.7904702551582523}
# {'fileName': 'book_The_Best_of_Lester_Del_Rey.csv', 'textSimilarityScore': 0.7904290546600127}
# {'fileName': 'book_Money_to_Burn.csv', 'textSimilarityScore': 0.7904244356450962}
# {'fileName': 'book_Blink.csv', 'textSimilarityScore': 0.7904113398456689}
# {'fileName': 'book_Tales_from_the_Perilous_Realm.csv', 'textSimilarityScore': 0.7904091041670108}
# {'fileName': 'book_American_Dragons.csv', 'textSimilarityScore': 0.7903983180983462}
# {'fileName': 'book_So_Yesterday.csv', 'textSimilarityScore': 0.7903898334932964}
# {'fileName': 'book_The_War_of_the_World.csv', 'textSimilarityScore': 0.7903879269140263}
# {'fileName': 'book_Orion.csv', 'textSimilarityScore': 0.7903697475938882}
# {'fileName': 'book_The_Complete_Shorter_Fiction_of_Virginia_Woolf.csv', 'textSimilarityScore': 0.7903662949331135}
# {'fileName': 'book_A_Journal.csv', 'textSimilarityScore': 0.7903560279193182}
# {'fileName': 'book_From_Socrates_to_Sartre.csv', 'textSimilarityScore': 0.7903509666012082}
# {'fileName': 'book_The_Virginia_Woolf_Reader.csv', 'textSimilarityScore': 0.7903469132561272}
# {'fileName': 'book_Infinite_Jests.csv', 'textSimilarityScore': 0.7903401562040473}
# {'fileName': 'book_The_Short_Stories_of_Ernest_Hemingway.csv', 'textSimilarityScore': 0.790288207271136}
# {'fileName': 'book_The_Collected_Stories_of_Eudora_Welty.csv', 'textSimilarityScore': 0.7902579223244903}
# {'fileName': 'book_Fire_Watch.csv', 'textSimilarityScore': 0.7902337458135674}
# {'fileName': 'book_Conversations_with_John_Updike.csv', 'textSimilarityScore': 0.7901620417221702}
# {'fileName': 'book_From_Far_Away.csv', 'textSimilarityScore': 0.7901376506593019}
# {'fileName': 'book_The_Phantom_Tollbooth.csv', 'textSimilarityScore': 0.7900563201284762}
# {'fileName': 'book_Stephen_King_from_A_to_Z.csv', 'textSimilarityScore': 0.7900429037432957}
# {'fileName': "book_Drina's_Dancing_Year.csv", 'textSimilarityScore': 0.7898969012074707}
# {'fileName': "book_McSweeney's_Enchanted_Chamber_of_Astonishing_Stories.csv", 'textSimilarityScore': 0.7898680568955342}
# {'fileName': 'book_The_Collected_Dorothy_Parker.csv', 'textSimilarityScore': 0.7898315894570433}
# {'fileName': 'book_The_Names.csv', 'textSimilarityScore': 0.7897935548960395}
# {'fileName': 'book_Sharp_Edges.csv', 'textSimilarityScore': 0.7897903590414956}
# {'fileName': 'book_The_Book_of_the_Dragon.csv', 'textSimilarityScore': 0.7897825858280253}
# {'fileName': 'book_Created_In_Darkness_By_Troubled_Americans.csv', 'textSimilarityScore': 0.7897815512555753}
# {'fileName': 'book_The_Collected_Poems_of_Robert_Penn_Warren.csv', 'textSimilarityScore': 0.7897644875665143}
# {'fileName': 'book_Jenny_and_the_Jaws_of_Life.csv', 'textSimilarityScore': 0.7897222645592108}
# {'fileName': 'book_The_Kate_DiCamillo_Collection.csv', 'textSimilarityScore': 0.7897127683495498}
# {'fileName': 'book_Moon-Flash.csv', 'textSimilarityScore': 0.7896683146323993}
# {'fileName': 'book_Diary.csv', 'textSimilarityScore': 0.7896602503331908}
# {'fileName': 'book_Bite.csv', 'textSimilarityScore': 0.7896312248596459}
# {'fileName': 'book_The_Bachman_Books.csv', 'textSimilarityScore': 0.7896108654642803}
# {'fileName': 'book_Sir_Gawain_and_the_Green_Knight,_Pearl,_and_Sir_Orfeo.csv', 'textSimilarityScore': 0.7895898705649214}
# {'fileName': 'book_Plagues_and_peoples.csv', 'textSimilarityScore': 0.789557447397942}
# {'fileName': 'book_Count_Zero.csv', 'textSimilarityScore': 0.7895286970198607}
# {'fileName': 'book_The_Complete_Stories.csv', 'textSimilarityScore': 0.7895136447041295}
# {'fileName': 'book_Wizard_and_Glass.csv', 'textSimilarityScore': 0.7894867022145959}
# {'fileName': 'book_The_Twelve_Terrors_of_Christmas.csv', 'textSimilarityScore': 0.7894568561431045}
# {'fileName': 'book_Young_Warriors.csv', 'textSimilarityScore': 0.7894466741243473}
# {'fileName': 'book_If_I_Die_in_a_Combat_Zone.csv', 'textSimilarityScore': 0.7894264762052349}
# {'fileName': 'book_Tinsel.csv', 'textSimilarityScore': 0.7894255778310071}
# {'fileName': 'book_Space.csv', 'textSimilarityScore': 0.7894232872737257}
# {'fileName': 'book_Voices.csv', 'textSimilarityScore': 0.7893823895846622}
# {'fileName': 'book_The_Book_of_Embraces.csv', 'textSimilarityScore': 0.7893613613785011}
# {'fileName': 'book_The_Double_Flame.csv', 'textSimilarityScore': 0.7893381077487435}
# {'fileName': 'book_Book_of_Nightmares.csv', 'textSimilarityScore': 0.7892321681519608}
# {'fileName': 'book_PS_I_Love_You_Baby_Collection.csv', 'textSimilarityScore': 0.789229782597493}
# {'fileName': "book_Janet_Flanner's_world.csv", 'textSimilarityScore': 0.7892186633634117}
# {'fileName': "book_Mother's_Milk.csv", 'textSimilarityScore': 0.7891987332223647}
# {'fileName': 'book_New_X-Men_-_Volume_1.csv', 'textSimilarityScore': 0.7891737161407139}
# {'fileName': 'book_The_Adventures_of_Pippi_Longstocking.csv', 'textSimilarityScore': 0.7891668615864802}
# {'fileName': "book_A_Routledge_Literary_Sourcebook_on_Herman_Melville's_Moby-Dick.csv", 'textSimilarityScore': 0.7891341531448732}
# {'fileName': 'book_The_Book_of_the_Dead.csv', 'textSimilarityScore': 0.7890678025692767}
# {'fileName': 'book_Complete_Stories_and_Poems_of_Edgar_Allan_Poe.csv', 'textSimilarityScore': 0.7890549033013643}
# {'fileName': 'book_Diary_of_a_Man_in_Despair.csv', 'textSimilarityScore': 0.7890478936690343}
# {'fileName': 'book_2061.csv', 'textSimilarityScore': 0.7890369625015423}
# {'fileName': 'book_Chilly_Scenes_of_Winter.csv', 'textSimilarityScore': 0.7890126587992174}
# {'fileName': 'book_Night_Lives.csv', 'textSimilarityScore': 0.7889918017167205}
# {'fileName': 'book_The_Heidi_Chronicles_and_Other_Plays.csv', 'textSimilarityScore': 0.7889764473326965}
# {'fileName': 'book_The_Review_of_Comtemporary_Fiction_-_Future_of_Fiction.csv', 'textSimilarityScore': 0.7889693192068549}
# {'fileName': "book_Vergil's_Aeneid.csv", 'textSimilarityScore': 0.7889406044685802}
# {'fileName': 'book_Roald_Dahl.csv', 'textSimilarityScore': 0.7889334251385096}
# {'fileName': 'book_Toys_Go_Out.csv', 'textSimilarityScore': 0.7889327156921196}
# {'fileName': 'book_Daphne_Dumaurier.csv', 'textSimilarityScore': 0.7888988948802365}
# {'fileName': 'book_Encyclopedia_Brown_and_the_Case_of_the_Treasure_Hunt.csv', 'textSimilarityScore': 0.7888792202596522}
# {'fileName': 'book_The_Great_Book_of_Amber.csv', 'textSimilarityScore': 0.788865620437788}
# {'fileName': 'book_Gabriel_García_Márquez__One_Hundred_Years_of_Solitude.csv', 'textSimilarityScore': 0.7888419080521555}
# {'fileName': 'news_Gangsters_dominate_gaming_chart.csv', 'textSimilarityScore': 0.7888149600115261}
# {'fileName': 'book_The_Minority_Report.csv', 'textSimilarityScore': 0.7887986673308567}
# {'fileName': 'book_Lightning.csv', 'textSimilarityScore': 0.7887942924782864}
# {'fileName': 'book_The_Uses_of_Literature.csv', 'textSimilarityScore': 0.7887664809903382}
# {'fileName': 'book_Bad_Boys_Over_Easy.csv', 'textSimilarityScore': 0.7887286459901247}
# {'fileName': 'book_The_Wood_Boy.csv', 'textSimilarityScore': 0.7887137816129078}
# {'fileName': 'book_The_Glory_and_the_Dream.csv', 'textSimilarityScore': 0.7887048824039502}
# {'fileName': 'book_Hideaway.csv', 'textSimilarityScore': 0.7887027163875122}
# {'fileName': 'book_The_World_Is_Flat_[Updated_and_Expanded].csv', 'textSimilarityScore': 0.7886985238335923}
# {'fileName': 'book_The_Complete_Collected_Poems_of_Maya_Angelou.csv', 'textSimilarityScore': 0.7886912144779448}
# {'fileName': 'book_The_Orwell_Reader.csv', 'textSimilarityScore': 0.7886727386440707}
# {'fileName': 'book_The_Pirate,_the_Adventurer_&_the_Cowboy.csv', 'textSimilarityScore': 0.7886668881854714}
# {'fileName': 'book_The_Magical_Worlds_of_the_Lord_of_the_Rings.csv', 'textSimilarityScore': 0.7886484042224007}
# {'fileName': 'book_Complete_Plays__1932-1943.csv', 'textSimilarityScore': 0.7885644696636831}
# {'fileName': 'book_The_Poetry_of_Pablo_Neruda.csv', 'textSimilarityScore': 0.7885219994164225}
# {'fileName': 'book_Four_Blondes.csv', 'textSimilarityScore': 0.7885086970269958}
# {'fileName': 'book_The_Empire_of_Ice_Cream.csv', 'textSimilarityScore': 0.7884913951149902}
# {'fileName': 'book_Searching_for_God_Knows_What.csv', 'textSimilarityScore': 0.7884800242326973}
# {'fileName': 'book_The_Value_of_X.csv', 'textSimilarityScore': 0.7884606182393361}
# {'fileName': 'book_The_Aviators.csv', 'textSimilarityScore': 0.7884158082867356}
# {'fileName': 'book_The_African_Trilogy.csv', 'textSimilarityScore': 0.7884157953637626}
# {'fileName': 'book_Seventeen_&_In-Between.csv', 'textSimilarityScore': 0.7884133903585908}
# {'fileName': "book_More_Readings_from_One_Man's_Wilderness.csv", 'textSimilarityScore': 0.7884103355357592}
# {'fileName': 'book_Drifters.csv', 'textSimilarityScore': 0.7883718892733882}
# {'fileName': 'book_Trojan_Odyssey.csv', 'textSimilarityScore': 0.7883651740576264}
# {'fileName': 'book_National_Geographic_Society.csv', 'textSimilarityScore': 0.7883634906460919}
# {'fileName': "book_Tell_Me_how_Long_the_Train's_Been_Gone.csv", 'textSimilarityScore': 0.7883571825801493}
# {'fileName': 'book_Writing_the_Novel_from_Plot_to_Print.csv', 'textSimilarityScore': 0.7883543421030206}
# {'fileName': 'book_A_Year_in_Provence.csv', 'textSimilarityScore': 0.7883522118668052}
# {'fileName': 'book_200_Quilt_Blocks_to_Mix_&_Match.csv', 'textSimilarityScore': 0.7883384496115148}
# {'fileName': 'book_Good_Poems_for_Hard_Times.csv', 'textSimilarityScore': 0.788299114781113}
# {'fileName': 'book_1491.csv', 'textSimilarityScore': 0.7882950701360995}
# {'fileName': 'book_The_Medusa_in_the_Shield.csv', 'textSimilarityScore': 0.7882844258834996}
# {'fileName': "book_The_World's_Religions.csv", 'textSimilarityScore': 0.788238422438619}
# {'fileName': 'book_Selected_Poems.csv', 'textSimilarityScore': 0.7882358872019868}
# {'fileName': 'book_The_Blue_Sword.csv', 'textSimilarityScore': 0.7882002324331255}
# {'fileName': 'book_All_Things_Bright_and_Beautiful.csv', 'textSimilarityScore': 0.7881912945188093}
# {'fileName': 'book_Bosnia.csv', 'textSimilarityScore': 0.7881844148756272}
# {'fileName': 'book_The_97th_Step.csv', 'textSimilarityScore': 0.7881611547615327}
# {'fileName': 'book_Dominion.csv', 'textSimilarityScore': 0.788157879854891}
# {'fileName': 'book_The_Stories_of_Vladimir_Nabokov.csv', 'textSimilarityScore': 0.7881373232669301}
# {'fileName': 'book_Exemplary_Novels.csv', 'textSimilarityScore': 0.7881312823183998}
# {'fileName': 'book_The_Blood_Wood.csv', 'textSimilarityScore': 0.7881281442732364}
# {'fileName': 'book_Twisted.csv', 'textSimilarityScore': 0.7881197911170971}
# {'fileName': 'book_The_diaries.csv', 'textSimilarityScore': 0.7881172074196061}
# {'fileName': 'book_Gates_Of_Fire.csv', 'textSimilarityScore': 0.7881135846692875}
# {'fileName': 'news_Paraguay_novel_wins_US_book_prize.csv', 'textSimilarityScore': 0.788074804443261}
# {'fileName': 'book_Blame_it_on_the_Blackout.csv', 'textSimilarityScore': 0.7880459608021388}
# {'fileName': 'book_Night_of_the_Long_Shadows.csv', 'textSimilarityScore': 0.7880362642199253}
# {'fileName': 'book_The_Lord_God_Made_Them_All.csv', 'textSimilarityScore': 0.7880266101085026}
# {'fileName': 'book_Life,_the_Universe_and_Everything.csv', 'textSimilarityScore': 0.7880223629321895}
# {'fileName': 'book_The_Bone_Collector.csv', 'textSimilarityScore': 0.7879458824321554}
# {'fileName': 'book_The_Columbia_Reader_on_Lesbians_and_Gay_Men_in_Media,_Society,_and_Politics.csv', 'textSimilarityScore': 0.7879368305069626}
# {'fileName': 'book_Eight_Little_Piggies.csv', 'textSimilarityScore': 0.7879198806143027}
# {'fileName': 'book_The_Covenant.csv', 'textSimilarityScore': 0.7878773508148194}
# {'fileName': 'book_The_Collected_Autobiographies_of_Maya_Angelou.csv', 'textSimilarityScore': 0.7878697373415606}
# {'fileName': 'book_The_Collected_Poems_of_Wilfred_Owen.csv', 'textSimilarityScore': 0.7877805460068492}
# {'fileName': 'book_Empire.csv', 'textSimilarityScore': 0.7877740709991444}
# {'fileName': "book_A_Young_Person's_Guide_to_Philosophy.csv", 'textSimilarityScore': 0.7877674827538772}
# {'fileName': 'book_Christian_Mythmakers.csv', 'textSimilarityScore': 0.7877356697653228}
# {'fileName': 'book_This_is_Push.csv', 'textSimilarityScore': 0.7877207009383622}
# {'fileName': 'book_The_Judy_Moody_Mood_Journal.csv', 'textSimilarityScore': 0.787710723797436}
# {'fileName': 'book_The_complete_guide_to_Middle-earth.csv', 'textSimilarityScore': 0.7876850953534958}
# {'fileName': 'book_The_Quiet_American.csv', 'textSimilarityScore': 0.7876669182654251}
# {'fileName': 'book_Sixteen_Thirty-two.csv', 'textSimilarityScore': 0.7876431473334442}
# {'fileName': 'book_Mr._Maybe.csv', 'textSimilarityScore': 0.7876007183208151}
# {'fileName': 'book_The_Poet,_the_Warrior,_the_Prophet.csv', 'textSimilarityScore': 0.7875851193809326}
# {'fileName': 'book_Collected_Poems.csv', 'textSimilarityScore': 0.7875624175712385}
# {'fileName': 'book_Hard_News.csv', 'textSimilarityScore': 0.7875430803278}
# {'fileName': 'book_Mysteries_of_Pittsburgh.csv', 'textSimilarityScore': 0.7875247334824743}
# {'fileName': 'book_The_Book_of_Lost_Tales.csv', 'textSimilarityScore': 0.7875159514005213}
# {'fileName': 'book_Triumph_of_the_Darksword.csv', 'textSimilarityScore': 0.7875098230712951}
# {'fileName': 'book_The_Beatles.csv', 'textSimilarityScore': 0.7874731627713196}
# {'fileName': 'book_The_Realm_of_Possibility.csv', 'textSimilarityScore': 0.7874565400769379}
# {'fileName': 'book_Tales_of_the_Norse_Gods.csv', 'textSimilarityScore': 0.7873837068683408}
# {'fileName': 'book_Songbook.csv', 'textSimilarityScore': 0.7873804408799951}
# {'fileName': 'book_The_Complete_Works_of_George_Orwell.csv', 'textSimilarityScore': 0.7873617893594578}
# {'fileName': 'book_The_Dead_Zone.csv', 'textSimilarityScore': 0.7873304812597692}
# {'fileName': 'book_Deception_Point.csv', 'textSimilarityScore': 0.7873186646865542}
# {'fileName': 'book_Summer_of_the_Monkeys.csv', 'textSimilarityScore': 0.7873125370722551}
# {'fileName': 'book_The_Illustrated_Book_of_Ballet_Stories.csv', 'textSimilarityScore': 0.787287317912742}
# {'fileName': 'book_The_Nuclear_Age.csv', 'textSimilarityScore': 0.787281096268376}
# {'fileName': "book_Hercule_Poirot's_Casebook.csv", 'textSimilarityScore': 0.78726879960844}
# {'fileName': 'book_Chuck_Klosterman_IV.csv', 'textSimilarityScore': 0.7872288855557572}
# {'fileName': 'book_Dead_Famous.csv', 'textSimilarityScore': 0.7872146591553024}
# {'fileName': 'book_Better_Than_Sex.csv', 'textSimilarityScore': 0.7871946111098274}
# {'fileName': 'book_The_Time_Machine.csv', 'textSimilarityScore': 0.7871686248577706}
# {'fileName': 'book_Bloodcurdling_Tales_of_Horror_and_the_Macabre__The_Best_of_H._P._Lovecraft.csv', 'textSimilarityScore': 0.7871625440251937}
# {'fileName': 'book_Orlando.csv', 'textSimilarityScore': 0.7871616743846591}
# {'fileName': 'book_Gunslinger,_and_Nine_Other_Action-packed_Stories_of_the_Wild_West.csv', 'textSimilarityScore': 0.7871451506229353}
# {'fileName': 'book_Gift_from_the_Sea.csv', 'textSimilarityScore': 0.7871158129615267}
# {'fileName': 'book_The_Years.csv', 'textSimilarityScore': 0.7871078326370335}
# {'fileName': 'book_The_Anthology_at_the_End_of_the_Universe.csv', 'textSimilarityScore': 0.7870966534635813}
# {'fileName': 'book_Americana.csv', 'textSimilarityScore': 0.7870705324635671}
# {'fileName': "book_Year's_Happy_Ending.csv", 'textSimilarityScore': 0.787050355412761}
# {'fileName': 'book_The_Major_Works.csv', 'textSimilarityScore': 0.7870121030591499}
# {'fileName': 'book_Preludes_and_Nocturnes.csv', 'textSimilarityScore': 0.7869819950867716}
# {'fileName': 'book_Flap_Your_Wings.csv', 'textSimilarityScore': 0.7869746768501061}
# {'fileName': 'book_Hit_Parade.csv', 'textSimilarityScore': 0.7869719359857515}

# %%
items_fts = await get_fulltext_search_results(container, questions[0], top_k=400)
print(f"Total items found: {len(items_fts)}")
for item in items_fts:
    print(item)

# %%
combined_results = combine_search_results(items_vector, items_fts)

print(f"Total items found: {len(combined_results)}")
for item in combined_results:
    print(item)

# %%
question_index = 5
print(f"Question: {questions[question_index]}")
with open(os.path.join("questions", f'question{question_index + 1}.txt'), 'r') as file:
    q1_lines = [line.strip() for line in file if line.strip()]

# Flatten multi-line entries (like Janet_My_Mother_and_Me.csv)
from itertools import groupby

q1_files = []
temp = []
for line in q1_lines:
    temp.append(line.replace("txt", "csv"))
    if line.endswith('.txt'):
        q1_files.append('_'.join(temp))
        temp = []
#search_query = "teenaged computer hacker"
search_query = questions[question_index]
embedding_result = await openai_helper.generate_embeddings([search_query], model="text-embedding-ada-002")
search_query_embedded = embedding_result[0].embedding
search_query_arr = search_query.split(" ")
# Out:
# Question: Give me wines tasted by Roger Voss
# embedding model: text-embedding-ada-002

# %%
r1 = get_vector_search_results(container, search_query_embedded, top_k=155, threshold=0.8)
for item in r1:
    print(item)

# %%
r2 = get_fulltext_search_results(container, search_query, top_k=155)
for item in r2:
    print(item)
# Out:
# ['Give', 'me', 'wines', 'tasted', 'by', 'Roger', 'Voss']
# {'fileName': 'student_Edward_Rogers.csv'}
# {'fileName': 'folk_tales_The_Old_Woman_and_the_Wine_Jar.csv'}
# {'fileName': 'folk_tales_The_Man_and_the_Wood.csv'}
# {'fileName': 'folk_tales_The_Little_Omelet.csv'}
# {'fileName': 'folk_tales_The_Serpent_and_the_File.csv'}
# {'fileName': 'folk_tales_The_Boy_Bathing.csv'}
# {'fileName': 'folk_tales_The_Fawn_and_His_Mother.csv'}
# {'fileName': 'folk_tales_The_Sun_and_the_Moon.csv'}
# {'fileName': 'folk_tales_The_Dolphin,_the_Whales_and_the_Sprat.csv'}
# {'fileName': 'folk_tales_The_Eagle_and_the_Arrow.csv'}
# {'fileName': 'folk_tales_Jupiter_and_the_Monkey.csv'}
# {'fileName': 'folk_tales_The_Dog_in_the_Manger.csv'}
# {'fileName': 'folk_tales_The_Man_Bitten_by_a_Dog.csv'}
# {'fileName': 'folk_tales_The_Wolf_and_the_Horse.csv'}
# {'fileName': 'book_Rita_Hayworth_and_Shawshank_Redemption.csv'}
# {'fileName': 'book_Goodbye_Forever.csv'}
# {'fileName': 'folk_tales_The_Ape.csv'}
# {'fileName': 'news_Blunkett_hints_at_election_call.csv'}
# {'fileName': 'folk_tales_The_Fox_and_the_Grapes.csv'}
# {'fileName': 'student_Chris_Garza.csv'}
# {'fileName': 'book_The_Portable_James_Joyce.csv'}
# {'fileName': 'student_Brittany_Smith.csv'}
# {'fileName': 'student_Jessica_Garrett.csv'}
# {'fileName': 'student_Logan_Mckinney_Jr..csv'}
# {'fileName': 'student_Megan_Chavez.csv'}
# {'fileName': 'student_Ryan_Atkinson.csv'}
# {'fileName': 'student_Daniel_Hutchinson.csv'}
# {'fileName': 'book_The_Builders.csv'}
# {'fileName': 'student_Angela_Prince.csv'}
# {'fileName': 'book_The_illustrated_man.csv'}
# {'fileName': 'book_The_Foundation_Trilogy.csv'}
# {'fileName': 'book_Cast_in_Dark_Waters.csv'}
# {'fileName': 'book_No_Fear___Julius_Caesar.csv'}
# {'fileName': 'book_Unspeakable_Truths.csv'}
# {'fileName': 'folk_tales_The_Dancing_Water,_the_Singing_Apple_and_the_Speaking_Bird.csv'}
# {'fileName': 'book_I,_Claudius_and_Claudius_the_God.csv'}
# {'fileName': 'folk_tales_The_Raven_and_the_Swan.csv'}
# {'fileName': 'student_Nathaniel_Garcia.csv'}
# {'fileName': 'book_The_British_Empiricists.csv'}
# {'fileName': 'book_Time_&_Again.csv'}
# {'fileName': 'book_A_Journal.csv'}
# {'fileName': 'student_Tanya_Goodwin.csv'}
# {'fileName': 'book_Eric.csv'}
# {'fileName': 'book_The_Secret_of_Santa_Vittoria.csv'}
# {'fileName': 'folk_tales_The_Dog_Chasing_a_Wolf.csv'}
# {'fileName': 'folk_tales_The_Charcoal-Burner_And_The_Fuller.csv'}
# {'fileName': 'student_Tiffany_Smith.csv'}
# {'fileName': 'book_Frankenstein__City_of_Night__A_Novel.csv'}
# {'fileName': 'book_An_Autobiography.csv'}
# {'fileName': 'student_Brandon_Smith.csv'}
# {'fileName': 'book_Marvel_1602.csv'}
# {'fileName': 'book_The_Taming_of_the_Shrew.csv'}
# {'fileName': 'student_Stephen_Brown.csv'}
# {'fileName': 'book_Best_Science_Fiction_Stories_of_Clifford_D._Simak.csv'}
# {'fileName': 'student_Debbie_Horne.csv'}
# {'fileName': 'student_Jessica_Wallace.csv'}
# {'fileName': 'book_The_Homecoming.csv'}
# {'fileName': 'book_Black_Sugar.csv'}
# {'fileName': 'book_The_Thirteenth_Tribe.csv'}
# {'fileName': 'student_Tiffany_Lozano.csv'}
# {'fileName': 'book_The_Patron_Saint_of_Liars.csv'}
# {'fileName': 'book_The_Moon_in_Hiding.csv'}
# {'fileName': 'folk_tales_The_Dog_and_the_Hides.csv'}
# {'fileName': 'student_Lisa_Glenn.csv'}
# {'fileName': 'folk_tales_The_Heifer_and_the_Ox.csv'}
# {'fileName': 'folk_tales_The_Four_Oxen_and_the_Lion.csv'}
# {'fileName': 'student_Jesse_Hardin.csv'}
# {'fileName': 'folk_tales_The_Lion_Beaten_by_the_Man.csv'}
# {'fileName': 'student_Kimberly_Ellison.csv'}
# {'fileName': 'student_Cameron_Terry.csv'}
# {'fileName': "book_Drina's_Dancing_Year.csv"}
# {'fileName': 'book_The_Art_of_Maurice_Sendak.csv'}
# {'fileName': 'student_Sherri_Perez.csv'}
# {'fileName': 'folk_tales_The_Flies_and_the_Honey-Pot.csv'}
# {'fileName': 'student_Jade_Dunlap.csv'}
# {'fileName': 'book_Story_of_Philosophy.csv'}
# {'fileName': 'book_The_Broken_Wings.csv'}
# {'fileName': 'book_The_Bone_Yard.csv'}
# {'fileName': 'book_The_diaries_of_Franz_Kafka.csv'}
# {'fileName': 'folk_tales_The_Peacock_and_the_Crane.csv'}
# {'fileName': 'book_The_Sundering.csv'}
# {'fileName': 'book_Plato,_with_an_English_Translation.csv'}
# {'fileName': 'student_Amanda_Hines.csv'}
# {'fileName': 'student_Richard_Cook.csv'}
# {'fileName': 'book_Collected_Stories.csv'}
# {'fileName': 'folk_tales_The_Boy_and_the_Nettles.csv'}
# {'fileName': 'book_Lawful_Possession.csv'}
# {'fileName': 'student_Gregory_Moreno.csv'}
# {'fileName': 'student_Jesse_Moss.csv'}
# {'fileName': 'book_What_is_Art_.csv'}
# {'fileName': 'book_The_Rape_of_Nanking.csv'}
# {'fileName': 'book_The_Loftier_Way.csv'}
# {'fileName': 'folk_tales_The_Runaway_Slave.csv'}
# {'fileName': 'student_Ronald_Baker.csv'}
# {'fileName': 'student_Matthew_Patel.csv'}
# {'fileName': 'student_Wendy_Cunningham.csv'}
# {'fileName': 'student_Kelly_Lee.csv'}
# {'fileName': 'folk_tales_The_Lamp.csv'}
# {'fileName': 'book_Medea.csv'}
# {'fileName': 'folk_tales_The_Blackamoor.csv'}
# {'fileName': 'book_This_Present_Darkness_;_Piercing_the_Darkness.csv'}
# {'fileName': 'book_..._The_Circulation.csv'}
# {'fileName': 'book_Space.csv'}
# {'fileName': 'student_Pamela_Barnes.csv'}
# {'fileName': 'book_The_Seasons__Summer.csv'}
# {'fileName': 'student_Donald_Davis.csv'}
# {'fileName': 'book_The_Complete_Greek_Tragedies.csv'}
# {'fileName': 'book_In_the_Country_of_Last_Things.csv'}
# {'fileName': "book_Gravity's_Rainbow.csv"}
# {'fileName': 'student_Douglas_Johnson.csv'}
# {'fileName': 'book_Exodus.csv'}
# {'fileName': 'book_The_Sleeping_Giant_and_Other_Stories.csv'}
# {'fileName': 'book_X-Men.csv'}
# {'fileName': 'book_Her_Little_Secret.csv'}
# {'fileName': 'folk_tales_The_Fox_and_the_Mask.csv'}
# {'fileName': 'student_Kenneth_Johnson.csv'}
# {'fileName': 'student_Sherry_Pittman.csv'}
# {'fileName': 'student_Rebecca_Lawson.csv'}
# {'fileName': 'student_Claire_Johnson.csv'}
# {'fileName': 'folk_tales_The_Ass_and_the_Old_Peasant.csv'}
# {'fileName': 'book_Billy_Budd.csv'}
# {'fileName': 'student_Peter_Mckay.csv'}
# {'fileName': 'book_The_Good_Housekeeping_Illustrated_Cookbook.csv'}
# {'fileName': 'book_The_Presocratics.csv'}
# {'fileName': 'book_The_Eight.csv'}
# {'fileName': 'folk_tales_The_Bald_Man_and_the_Fly.csv'}
# {'fileName': 'book_Novels_1957-1962.csv'}
# {'fileName': 'book_Babysitters_Club.csv'}
# {'fileName': 'folk_tales_The_Traveler_and_His_Dog.csv'}
# {'fileName': 'book_Fantastic_Four.csv'}
# {'fileName': 'folk_tales_The_Prophet.csv'}
# {'fileName': 'book_Shadowkill.csv'}
# {'fileName': 'student_Bobby_Castro.csv'}
# {'fileName': 'student_Kelly_Stewart.csv'}
# {'fileName': 'book_The_New_Spirit.csv'}
# {'fileName': 'book_The_Bachman_Books.csv'}
# {'fileName': 'student_Ashlee_Jimenez.csv'}
# {'fileName': 'book_The_Greatest_Salesman_in_the_World.csv'}
# {'fileName': 'book_Tolkien_on_film.csv'}
# {'fileName': 'folk_tales_The_Boasting_Traveler.csv'}
# {'fileName': 'book_P.S._I_Love_You.csv'}
# {'fileName': 'student_Todd_Harris.csv'}
# {'fileName': 'book_About_a_Boy.csv'}
# {'fileName': 'student_Jonathon_Wilson.csv'}
# {'fileName': 'book_The_complete_works_of_Aristotle.csv'}
# {'fileName': 'folk_tales_The_Woman_and_Her_Hen.csv'}
# {'fileName': 'book_Purity.csv'}
# {'fileName': 'book_The_best_of_Philip_K._Dick.csv'}
# {'fileName': 'book_The_Subterraneans.csv'}
# {'fileName': 'folk_tales_A_Riddling_Tale.csv'}
# {'fileName': 'book_2061.csv'}
# {'fileName': 'book_The_Abhorsen_Trilogy.csv'}
# {'fileName': 'book_The_Subtle_Knife.csv'}
# {'fileName': 'student_Larry_Rodriguez.csv'}
# {'fileName': 'folk_tales_The_Oaks_and_Jupiter.csv'}

# %%
combined_results = combine_search_results(r1, r2)
print(f"Total items found: {len(combined_results)}")
for item in combined_results:
    print(item)
# Out:
# Total items found: 310
# {'fileName': 'book_..._The_Circulation.csv'}
# {'fileName': 'book_2061.csv'}
# {'fileName': 'book_A_Journal.csv'}
# {'fileName': 'book_About_a_Boy.csv'}
# {'fileName': 'book_An_Autobiography.csv'}
# {'fileName': 'book_Babysitters_Club.csv'}
# {'fileName': 'book_Best_Science_Fiction_Stories_of_Clifford_D._Simak.csv'}
# {'fileName': 'book_Billy_Budd.csv'}
# {'fileName': 'book_Black_Sugar.csv'}
# {'fileName': 'book_Cast_in_Dark_Waters.csv'}
# {'fileName': 'book_Collected_Stories.csv'}
# {'fileName': "book_Drina's_Dancing_Year.csv"}
# {'fileName': 'book_Eric.csv'}
# {'fileName': 'book_Exodus.csv'}
# {'fileName': 'book_Fantastic_Four.csv'}
# {'fileName': 'book_Frankenstein__City_of_Night__A_Novel.csv'}
# {'fileName': 'book_Goodbye_Forever.csv'}
# {'fileName': "book_Gravity's_Rainbow.csv"}
# {'fileName': 'book_Her_Little_Secret.csv'}
# {'fileName': 'book_I,_Claudius_and_Claudius_the_God.csv'}
# {'fileName': 'book_In_the_Country_of_Last_Things.csv'}
# {'fileName': 'book_Lawful_Possession.csv'}
# {'fileName': 'book_Marvel_1602.csv'}
# {'fileName': 'book_Medea.csv'}
# {'fileName': 'book_No_Fear___Julius_Caesar.csv'}
# {'fileName': 'book_Novels_1957-1962.csv'}
# {'fileName': 'book_P.S._I_Love_You.csv'}
# {'fileName': 'book_Plato,_with_an_English_Translation.csv'}
# {'fileName': 'book_Purity.csv'}
# {'fileName': 'book_Rita_Hayworth_and_Shawshank_Redemption.csv'}
# {'fileName': 'book_Shadowkill.csv'}
# {'fileName': 'book_Space.csv'}
# {'fileName': 'book_Story_of_Philosophy.csv'}
# {'fileName': 'book_The_Abhorsen_Trilogy.csv'}
# {'fileName': 'book_The_Art_of_Maurice_Sendak.csv'}
# {'fileName': 'book_The_Bachman_Books.csv'}
# {'fileName': 'book_The_Bone_Yard.csv'}
# {'fileName': 'book_The_British_Empiricists.csv'}
# {'fileName': 'book_The_Broken_Wings.csv'}
# {'fileName': 'book_The_Builders.csv'}
# {'fileName': 'book_The_Complete_Greek_Tragedies.csv'}
# {'fileName': 'book_The_Eight.csv'}
# {'fileName': 'book_The_Foundation_Trilogy.csv'}
# {'fileName': 'book_The_Good_Housekeeping_Illustrated_Cookbook.csv'}
# {'fileName': 'book_The_Greatest_Salesman_in_the_World.csv'}
# {'fileName': 'book_The_Homecoming.csv'}
# {'fileName': 'book_The_Loftier_Way.csv'}
# {'fileName': 'book_The_Moon_in_Hiding.csv'}
# {'fileName': 'book_The_New_Spirit.csv'}
# {'fileName': 'book_The_Patron_Saint_of_Liars.csv'}
# {'fileName': 'book_The_Portable_James_Joyce.csv'}
# {'fileName': 'book_The_Presocratics.csv'}
# {'fileName': 'book_The_Rape_of_Nanking.csv'}
# {'fileName': 'book_The_Seasons__Summer.csv'}
# {'fileName': 'book_The_Secret_of_Santa_Vittoria.csv'}
# {'fileName': 'book_The_Sleeping_Giant_and_Other_Stories.csv'}
# {'fileName': 'book_The_Subterraneans.csv'}
# {'fileName': 'book_The_Subtle_Knife.csv'}
# {'fileName': 'book_The_Sundering.csv'}
# {'fileName': 'book_The_Taming_of_the_Shrew.csv'}
# {'fileName': 'book_The_Thirteenth_Tribe.csv'}
# {'fileName': 'book_The_best_of_Philip_K._Dick.csv'}
# {'fileName': 'book_The_complete_works_of_Aristotle.csv'}
# {'fileName': 'book_The_diaries_of_Franz_Kafka.csv'}
# {'fileName': 'book_The_illustrated_man.csv'}
# {'fileName': 'book_This_Present_Darkness_;_Piercing_the_Darkness.csv'}
# {'fileName': 'book_Time_&_Again.csv'}
# {'fileName': 'book_Tolkien_on_film.csv'}
# {'fileName': 'book_Unspeakable_Truths.csv'}
# {'fileName': 'book_What_is_Art_.csv'}
# {'fileName': 'book_X-Men.csv'}
# {'fileName': 'folk_tales_A_Riddling_Tale.csv'}
# {'fileName': 'folk_tales_Jupiter_and_the_Monkey.csv'}
# {'fileName': 'folk_tales_The_Ape.csv'}
# {'fileName': 'folk_tales_The_Ass_and_the_Old_Peasant.csv'}
# {'fileName': 'folk_tales_The_Bald_Man_and_the_Fly.csv'}
# {'fileName': 'folk_tales_The_Blackamoor.csv'}
# {'fileName': 'folk_tales_The_Boasting_Traveler.csv'}
# {'fileName': 'folk_tales_The_Boy_Bathing.csv'}
# {'fileName': 'folk_tales_The_Boy_and_the_Nettles.csv'}
# {'fileName': 'folk_tales_The_Charcoal-Burner_And_The_Fuller.csv'}
# {'fileName': 'folk_tales_The_Dancing_Water,_the_Singing_Apple_and_the_Speaking_Bird.csv'}
# {'fileName': 'folk_tales_The_Dog_Chasing_a_Wolf.csv'}
# {'fileName': 'folk_tales_The_Dog_and_the_Hides.csv'}
# {'fileName': 'folk_tales_The_Dog_in_the_Manger.csv'}
# {'fileName': 'folk_tales_The_Dolphin,_the_Whales_and_the_Sprat.csv'}
# {'fileName': 'folk_tales_The_Eagle_and_the_Arrow.csv'}
# {'fileName': 'folk_tales_The_Fawn_and_His_Mother.csv'}
# {'fileName': 'folk_tales_The_Flies_and_the_Honey-Pot.csv'}
# {'fileName': 'folk_tales_The_Four_Oxen_and_the_Lion.csv'}
# {'fileName': 'folk_tales_The_Fox_and_the_Grapes.csv'}
# {'fileName': 'folk_tales_The_Fox_and_the_Mask.csv'}
# {'fileName': 'folk_tales_The_Heifer_and_the_Ox.csv'}
# {'fileName': 'folk_tales_The_Lamp.csv'}
# {'fileName': 'folk_tales_The_Lion_Beaten_by_the_Man.csv'}
# {'fileName': 'folk_tales_The_Little_Omelet.csv'}
# {'fileName': 'folk_tales_The_Man_Bitten_by_a_Dog.csv'}
# {'fileName': 'folk_tales_The_Man_and_the_Wood.csv'}
# {'fileName': 'folk_tales_The_Oaks_and_Jupiter.csv'}
# {'fileName': 'folk_tales_The_Old_Woman_and_the_Wine_Jar.csv'}
# {'fileName': 'folk_tales_The_Peacock_and_the_Crane.csv'}
# {'fileName': 'folk_tales_The_Prophet.csv'}
# {'fileName': 'folk_tales_The_Raven_and_the_Swan.csv'}
# {'fileName': 'folk_tales_The_Runaway_Slave.csv'}
# {'fileName': 'folk_tales_The_Serpent_and_the_File.csv'}
# {'fileName': 'folk_tales_The_Sun_and_the_Moon.csv'}
# {'fileName': 'folk_tales_The_Traveler_and_His_Dog.csv'}
# {'fileName': 'folk_tales_The_Wolf_and_the_Horse.csv'}
# {'fileName': 'folk_tales_The_Woman_and_Her_Hen.csv'}
# {'fileName': 'news_Blunkett_hints_at_election_call.csv'}
# {'fileName': 'student_Amanda_Hines.csv'}
# {'fileName': 'student_Angela_Prince.csv'}
# {'fileName': 'student_Ashlee_Jimenez.csv'}
# {'fileName': 'student_Bobby_Castro.csv'}
# {'fileName': 'student_Brandon_Smith.csv'}
# {'fileName': 'student_Brittany_Smith.csv'}
# {'fileName': 'student_Cameron_Terry.csv'}
# {'fileName': 'student_Chris_Garza.csv'}
# {'fileName': 'student_Claire_Johnson.csv'}
# {'fileName': 'student_Daniel_Hutchinson.csv'}
# {'fileName': 'student_Debbie_Horne.csv'}
# {'fileName': 'student_Donald_Davis.csv'}
# {'fileName': 'student_Douglas_Johnson.csv'}
# {'fileName': 'student_Edward_Rogers.csv'}
# {'fileName': 'student_Gregory_Moreno.csv'}
# {'fileName': 'student_Jade_Dunlap.csv'}
# {'fileName': 'student_Jesse_Hardin.csv'}
# {'fileName': 'student_Jesse_Moss.csv'}
# {'fileName': 'student_Jessica_Garrett.csv'}
# {'fileName': 'student_Jessica_Wallace.csv'}
# {'fileName': 'student_Jonathon_Wilson.csv'}
# {'fileName': 'student_Kelly_Lee.csv'}
# {'fileName': 'student_Kelly_Stewart.csv'}
# {'fileName': 'student_Kenneth_Johnson.csv'}
# {'fileName': 'student_Kimberly_Ellison.csv'}
# {'fileName': 'student_Larry_Rodriguez.csv'}
# {'fileName': 'student_Lisa_Glenn.csv'}
# {'fileName': 'student_Logan_Mckinney_Jr..csv'}
# {'fileName': 'student_Matthew_Patel.csv'}
# {'fileName': 'student_Megan_Chavez.csv'}
# {'fileName': 'student_Nathaniel_Garcia.csv'}
# {'fileName': 'student_Pamela_Barnes.csv'}
# {'fileName': 'student_Peter_Mckay.csv'}
# {'fileName': 'student_Rebecca_Lawson.csv'}
# {'fileName': 'student_Richard_Cook.csv'}
# {'fileName': 'student_Ronald_Baker.csv'}
# {'fileName': 'student_Ryan_Atkinson.csv'}
# {'fileName': 'student_Sherri_Perez.csv'}
# {'fileName': 'student_Sherry_Pittman.csv'}
# {'fileName': 'student_Stephen_Brown.csv'}
# {'fileName': 'student_Tanya_Goodwin.csv'}
# {'fileName': 'student_Tiffany_Lozano.csv'}
# {'fileName': 'student_Tiffany_Smith.csv'}
# {'fileName': 'student_Todd_Harris.csv'}
# {'fileName': 'student_Wendy_Cunningham.csv'}
# {'fileName': 'wine_1912_Winemakers_2009_Piorro_Reserva_Red_(Douro).csv'}
# {'fileName': 'wine_21_Grams_2011_Red_(Washington).csv'}
# {'fileName': 'wine_André_Kientzler_2015_Geisberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_André_Kientzler_2016_Osterberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Anton_Bauer_2014_Pinot_Noir_(Wagram).csv'}
# {'fileName': 'wine_B_Vintners_2016_Cape_Winemakers_Guild_Inboet_Storie_Cinsault_(Stellenbosch).csv'}
# {'fileName': 'wine_Bartho_Eksteen_2015_Cape_Winemakers_Guild_Vloekskoot_Wooded_Sauvignon_Blanc_(Hemel_en_Aarde).csv'}
# {'fileName': 'wine_Bartho_Eksteen_2016_Cape_Winemakers_Guild_Vloekskoot_Wooded_Sauvignon_Blanc.csv'}
# {'fileName': 'wine_Barton_2011_Mr._Jones_Grenache_(Paso_Robles).csv'}
# {'fileName': 'wine_Biecher_&_Schaal_2015_Schoenenbourg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Boeckel_2014_Wiebelsberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Boeckel_2015_Zotzenberg_Grand_Cru_Pinot_Gris_(Alsace).csv'}
# {'fileName': 'wine_Boeckel_2015_Zotzenberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Boudreaux_Cellars_2004_Champoux_Vineyard_Reserve_Cabernet_Sauvignon_(Horse_Heaven_Hills).csv'}
# {'fileName': 'wine_Brennan_2015_Cellar_Select_Viognier_(Texas).csv'}
# {'fileName': 'wine_Bride_Valley_Vineyard_2014_Rosé_Bella_Sparkling_(England).csv'}
# {'fileName': 'wine_Capitain-Gagnerot_2013__Echézeaux.csv'}
# {'fileName': 'wine_Cave_de_Ribeauvillé_2010_Osterberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Château_Côte_Montpezat_2015__Bordeaux_Blanc.csv'}
# {'fileName': 'wine_Château_Haut-Monplaisir_2014_Pur_Plaisir_Malbec_(Cahors).csv'}
# {'fileName': 'wine_Château_Joanin_Bécot_2012__Castillon_Côtes_de_Bordeaux.csv'}
# {'fileName': 'wine_Château_Lagrézette_2014_Mas_de_Merveilles_Viognier_(Côtes_du_Lot).csv'}
# {'fileName': 'wine_Château_Larroque_2014__Bordeaux_Blanc.csv'}
# {'fileName': 'wine_Château_Potelle_2004_VGS_Cabernet_Sauvignon_(Mount_Veeder).csv'}
# {'fileName': "wine_Château_d'Eck_2013__Pessac-Léognan.csv"}
# {'fileName': 'wine_DeMorgenzon_2016_Cape_Winemakers_Guild_Roussanne_(Stellenbosch).csv'}
# {'fileName': 'wine_De_Toren_2008_Fusion_V_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_De_Toren_2010_Fusion_V_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_De_Toren_2011_Fusion_V_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_De_Toren_2012_Fusion_V_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_Domaine_Barmès-Buecher_2014_Rosenberg_Gewurztraminer_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Barmès-Buecher_2015_Hengst_Grand_Cru_Gewurztraminer_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Barmès-Buecher_2015_Rosenberg_Vieilles_Vignes_Sylvaner_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Charles_Frey_2015_Frankstein_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Gresser_2012_Wiebelsberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_La_Tour_Penedesses_2010_Les_Volcans_Red_(Coteaux_du_Languedoc-Pézenas).csv'}
# {'fileName': 'wine_Domaine_Ostertag_2014_A360P_Muenchberg_Grand_Cru_Pinot_Gris_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Ostertag_2014_Fronholz_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Ostertag_2015_A360P_Muenchberg_Grand_Cru_Pinot_Gris_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Ostertag_2015_Fronholz_Pinot_Gris_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Schoffit_2015_Clos_Saint-Théobald_Rangen_Grand_Cru_Vendanges_Tardives_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Sipp-Mack_2014_Osterberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Thunevin-Calvet_2008_Hugo_Red_(Côtes_du_Roussillon_Villages).csv'}
# {'fileName': 'wine_Domaine_Zind-Humbrecht_2014_Clos_Windsbuhl_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_Zind-Humbrecht_2015_Roche_Volcanique_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Domaine_de_la_Cote_2012_la_Cote_Pinot_Noir_(Sta._Rita_Hills).csv'}
# {'fileName': 'wine_Domaine_du_Castel_2006_Grand_Vin_Kosher_Red_(Judean_Hills).csv'}
# {'fileName': 'wine_Domaine_du_Castel_2007_Grand_Vin_Red_(Haut-Judeé).csv'}
# {'fileName': 'wine_Domaine_du_Castel_2009_Grand_Vin_Red_(Haut-Judeé).csv'}
# {'fileName': 'wine_Domaines_Schlumberger_2013_Vendanges_Tardives_Cuvée_Christine_Gewurztraminer_(Alsace).csv'}
# {'fileName': 'wine_Domäne_Wachau_2012_Kellerberg_Smaragd_Riesling_(Wachau).csv'}
# {'fileName': 'wine_Egon_Müller_2015_Scharzhofberger_Spätlese_Riesling_(Mosel).csv'}
# {'fileName': 'wine_Ernie_Els_2014_Cape_Winemakers_Guild_CWG_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_F_X_Pichler_2013_Loibner_Steinertal_Smaragd_Grüner_Veltliner_(Wachau).csv'}
# {'fileName': 'wine_Figgins_2010_Estate_Red_(Walla_Walla_Valley_(WA)).csv'}
# {'fileName': 'wine_Fischer_2014_Reserve_Privat_Grüner_Veltliner_(Wachau).csv'}
# {'fileName': 'wine_Foxen_2010_Toasted_Rope_Syrah_(Santa_Ynez_Valley).csv'}
# {'fileName': 'wine_Franz_Hirtzberger_2014_Honivogl_Smaragd_Grüner_Veltliner_(Wachau).csv'}
# {'fileName': 'wine_Gary_Farrell_2009_Rochioli_Vineyard_Chardonnay_(Russian_River_Valley).csv'}
# {'fileName': 'wine_Gérard_Bertrand_1945_Legend_Vintage_Red_(Rivesaltes).csv'}
# {'fileName': 'wine_Gérard_Bertrand_2011_Château_de_Villemajou_Grand_Vin_Red_(Corbières-Boutenac).csv'}
# {'fileName': 'wine_Gérard_Bertrand_2011_Tautavel_Hommage_aux_Vignerons_Red_(Côtes_du_Roussillon_Villages_Tautavel).csv'}
# {'fileName': 'wine_Gérard_Bertrand_2014_Château_La_Sauvageonne_GMVV_Rosé_(Coteaux_du_Languedoc).csv'}
# {'fileName': "wine_Gérard_Bertrand_2014_L'Hospitalet_Grand_Vin_White_(La_Clape).csv"}
# {'fileName': 'wine_Gottfried_Mocke_Wine_Projects_2016_Cape_Winemakers_Guild_Pinot_Noir_(Overberg).csv'}
# {'fileName': 'wine_Guardian_2006_Syrah_(Columbia_Valley_(WA)).csv'}
# {'fileName': 'wine_Harper_Voit_2013_Strandline_Pinot_Noir_(Willamette_Valley).csv'}
# {'fileName': 'wine_Hecho_por_Ruben_2012_Harrison_Clarke_Vineyard_Syrah_(Ballard_Canyon).csv'}
# {'fileName': "wine_I'M_2007_Pinot_Noir_(Willamette_Valley).csv"}
# {'fileName': 'wine_Jean-Baptiste_Adam_2015_Wineck-Schlossberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Jean_Biecher_&_Fils_2016_Sommerberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Johanneshof_Reinisch_2013_Frauenfeld_St._Laurent_(Thermenregion).csv'}
# {'fileName': 'wine_Johanneshof_Reinisch_2014_Rotgipfler_(Thermenregion).csv'}
# {'fileName': 'wine_Jordan_Stellenbosch_2015_Cape_Winemakers_Guild_CWG_Chardonnay_(Stellenbosch).csv'}
# {'fileName': 'wine_Kracher_2013_Grande_Cuvée_Trockenbeerenauslese_Nummer_6_Nouvelle_Vague_White_(Burgenland).csv'}
# {'fileName': 'wine_Lauren_Ashton_Cellars_2011_Cuvée_Arlette_Red_(Columbia_Valley_(WA)).csv'}
# {'fileName': 'wine_Le_Cadeau_2006_Rocheux_Pinot_Noir_(Willamette_Valley).csv'}
# {'fileName': 'wine_Le_Cadeau_2012_Rocheux_Reserve_Pinot_Noir_(Chehalem_Mountains).csv'}
# {'fileName': 'wine_Le_Cadeau_2015_Rocheux_Pinot_Noir_(Willamette_Valley).csv'}
# {'fileName': 'wine_Le_Fraghe_2016_Rodon__(Bardolino_Chiaretto).csv'}
# {'fileName': 'wine_Le_Mulet_Rouge_2016_Estate_Viognier_(Fiddletown).csv'}
# {'fileName': 'wine_Leth_2015_Hofweingarten_Roter_Veltliner_(Wagram).csv'}
# {'fileName': 'wine_Louis_Roederer_2008_Cristal_Brut_Rosé__(Champagne).csv'}
# {'fileName': 'wine_Louis_Roederer_2008_Cristal_Vintage_Brut__(Champagne).csv'}
# {'fileName': 'wine_Louis_Roederer_2009_Cristal_Brut__(Champagne).csv'}
# {'fileName': 'wine_Louis_Sipp_2010_Osterberg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': "wine_Lovingston_2012_Josie's_Knoll_Merlot_(Monticello).csv"}
# {'fileName': 'wine_Maison_Bleue_2014_Bourgeois_Grenache_(Walla_Walla_Valley_(WA)).csv'}
# {'fileName': 'wine_Mayer_am_Pfarrplatz_2015_White_(Wiener_Gemischter_Satz).csv'}
# {'fileName': 'wine_Meerlust_2014_Chardonnay_(Stellenbosch).csv'}
# {'fileName': 'wine_Minimus_2015_Vitae_Springs_Vineyard_Grüner_Veltliner_(Willamette_Valley).csv'}
# {'fileName': 'wine_Moss_Wood_2011_Cabernet_Sauvignon_(Margaret_River).csv'}
# {'fileName': 'wine_Muratie_2006_Ronnie_Melck_A_Tribute_Shiraz_(Simonsberg-Stellenbosch).csv'}
# {'fileName': 'wine_Mvemve_Raats_2014_MR_de_Compostella_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_Nicora_2013_Russell_Family_Vineyard_Syrah_(Paso_Robles_Willow_Creek_District).csv'}
# {'fileName': 'wine_Olsen_Estates_2008_Rouge_des_Coteaux_Red_(Yakima_Valley).csv'}
# {'fileName': 'wine_Paul_Cluver_2014_Cape_Winemakers_Guild_Auction_Selection_Pinot_Noir_(Elgin).csv'}
# {'fileName': 'wine_Paul_Cluver_2015_Cape_Winemakers_Guild_Auction_Selection_Pinot_Noir_(Elgin).csv'}
# {'fileName': 'wine_Piro_2015_Points_West_Pinot_Noir_(Santa_Maria_Valley).csv'}
# {'fileName': 'wine_Pittnauer_2013_Rosenberg_St._Laurent_(Burgenland).csv'}
# {'fileName': 'wine_Portfolio_2005_Limited_Edition_Red_(Napa_Valley).csv'}
# {'fileName': 'wine_Portfolio_2012_Red_(Napa_Valley).csv'}
# {'fileName': 'wine_Portfolio_2013_Limited_Edition_Red_(Napa_Valley).csv'}
# {'fileName': 'wine_Quinta_Vale_Dona_Maria_2013_Vinha_do_Rio_Red_(Douro).csv'}
# {'fileName': 'wine_Quinta_da_Foz_2011_Reserva_Red_(Douro).csv'}
# {'fileName': 'wine_Quinta_de_la_Rosa_2014_Reserva_Branco_White_(Douro).csv'}
# {'fileName': 'wine_Raats_Family_2010_Cabernet_Franc_(Stellenbosch).csv'}
# {'fileName': 'wine_Raats_Family_2013_Red_Jasper_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_René_Muré_2013_Clos_Saint_Landelin_Vorbourg_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Rexford_2010_Brosseau_Vineyard_Pinot_Noir_(Chalone).csv'}
# {'fileName': 'wine_Résonance_2013_Résonance_Vineyard_Pinot_Noir.csv'}
# {'fileName': 'wine_Résonance_2014_Pinot_Noir_(Willamette_Valley).csv'}
# {'fileName': 'wine_Résonance_2014_Résonance_Vineyard_Pinot_Noir.csv'}
# {'fileName': "wine_Rijk's_2015_Cape_Winemakers_Guild_CWG_Chenin_Blanc_(Tulbagh).csv"}
# {'fileName': 'wine_Riverhaven_2007_Riverrock_Vineyards_Cabernet_Sauvignon_(Walla_Walla_Valley_(OR)).csv'}
# {'fileName': 'wine_Roco_2013_RMS_Brut_Sparkling_(Willamette_Valley).csv'}
# {'fileName': 'wine_Roessler_2004_Wiley_Vineyard_Riesling_(Anderson_Valley).csv'}
# {'fileName': 'wine_Rosenhof_2012_Orion_Eiswein_Grüner_Veltliner_(Burgenland).csv'}
# {'fileName': 'wine_Rosenhof_2014_Trockenbeerenauslese_Grüner_Veltliner_(Burgenland).csv'}
# {'fileName': 'wine_Rosenhof_2015_Orion_Eiswein_Grüner_Veltliner_(Burgenland).csv'}
# {'fileName': 'wine_Rust_en_Vrede_2010_Cabernet_Sauvignon_(Stellenbosch).csv'}
# {'fileName': 'wine_Rust_en_Vrede_2013_Cabernet_Sauvignon_(Stellenbosch).csv'}
# {'fileName': 'wine_Rust_en_Vrede_2013_Cape_Winemakers_Guild_CWG_Auction_Estate_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_Salomon-Undhof_2015_Steiner_Kögl_Reserve_Riesling_(Kremstal).csv'}
# {'fileName': 'wine_Schloss_Vollrads_2007_Trockenbeerenauslese_-_375_ml_Riesling_(Rheingau).csv'}
# {'fileName': 'wine_Schramsberg_2008_J._Schram_Rosé_(North_Coast).csv'}
# {'fileName': 'wine_Simonsig_2007_Cape_Winemakers_Guild_Cuvée_Chêne_Blanc_de_Blancs_Chardonnay_(Stellenbosch).csv'}
# {'fileName': 'wine_Simonsig_2015_Cape_Winemakers_Guild_Mediterraneo_White_(Stellenbosch).csv'}
# {'fileName': 'wine_Tensley_2015_OGT_Syrah_(Santa_Barbara_County).csv'}
# {'fileName': 'wine_Terrassous_1992_Vin_Doux_Naturel_White_(Rivesaltes).csv'}
# {'fileName': 'wine_Testarossa_2011_Graham_Family_Vineyard_Pinot_Noir_(Russian_River_Valley).csv'}
# {'fileName': "wine_Testarossa_2014_Garys'_Vineyard_Pinot_Noir_(Santa_Lucia_Highlands).csv"}
# {'fileName': 'wine_The_Grapes_of_Roth_2012_Merlot_(North_Fork_of_Long_Island).csv'}
# {'fileName': 'wine_Vadio_Wines_2005_Vadio_Baga_(Bairrada).csv'}
# {'fileName': 'wine_Vadio_Wines_2011_Vadio_Baga_(Bairrada).csv'}
# {'fileName': 'wine_Velocity_2007_Red_Wine_Red_(Rogue_Valley).csv'}
# {'fileName': 'wine_Viader_2008_Red_(Napa_Valley).csv'}
# {'fileName': 'wine_Vidon_Vineyard_2007_Three_Clones_Pinot_Noir_(Chehalem_Mountains).csv'}
# {'fileName': 'wine_Viento_2006_Columbia_Gorge_Vineyard_Riesling_(Columbia_Gorge_(OR)).csv'}
# {'fileName': 'wine_Vilafonté_2007_Series_C_Red_(Paarl).csv'}
# {'fileName': 'wine_Vilafonté_2014_Series_C_Red_(Paarl).csv'}
# {'fileName': 'wine_Vina_Robles_2013_Suendero_Red_(Paso_Robles).csv'}
# {'fileName': 'wine_Viña_La_Rosa_2007_Ossa_Sixth_Generation_Red_(Cachapoal_Valley).csv'}
# {'fileName': 'wine_Volker_Eisele_Family_Estate_2006_Gemini_White_Wine_White_(Napa_Valley).csv'}
# {'fileName': 'wine_Volker_Eisele_Family_Estate_2012_Cabernet_Sauvignon_(Napa_Valley).csv'}
# {'fileName': "wine_W._&_J._Graham's_NV_Six_Grapes_Special_Old_Vine_Edition__(Port).csv"}
# {'fileName': 'wine_Waterford_2014_Cape_Winemakers_Guild_BB_Red_(Stellenbosch).csv'}
# {'fileName': 'wine_Wayfarer_2014_Wayfarer_Vineyard_Chardonnay_(Fort_Ross-Seaview).csv'}
# {'fileName': 'wine_Wieninger_2015_Select_Pinot_Noir_(Vienna).csv'}
# {'fileName': 'wine_Willamette_Valley_Vineyards_2006_Signature_Cuvée_Pinot_Noir_(Willamette_Valley).csv'}
# {'fileName': 'wine_Wiston_Estate_Winery_2014_Rosé_Sparkling_(England).csv'}
# {'fileName': 'wine_Wolfberger_2014_Rangen_Grand_Cru_Riesling_(Alsace).csv'}
# {'fileName': 'wine_Woodward_Canyon_2006_Old_Vines_Dedication_Series_#26_Cabernet_Sauvignon_(Columbia_Valley_(WA)).csv'}
# {'fileName': 'wine_Woodward_Canyon_2012_Old_Vines_Cabernet_Sauvignon_(Washington).csv'}
# {'fileName': 'wine_Y_Rousseau_2015_Old_Vines_Colombard_(Russian_River_Valley).csv'}

# %%
q1_set = set(q1_files)
item_files_set = {item['fileName'] for item in combined_results}

missing_in_items = q1_set - item_files_set
extra_in_items = item_files_set - q1_set

print("Count of files in q1.txt but missing in search:", len(missing_in_items))

# correct recall calculation
recall = (len(q1_set) - len(missing_in_items)) / len(q1_set) * 100
print(f"Recall: {recall:.2f}%")
# Out:
# Count of files in q1.txt but missing in search: 81
# Recall: 17.35%

# %%
#%%skip

items = container.query_items( 
query="""SELECT top 200 c.fileName, VectorDistance(c.textVector, @embedding) AS textSimilarityScore 
FROM c
WHERE VectorDistance(c.textVector, @embedding) > 0.7
ORDER BY VectorDistance(c.textVector, @embedding) 
""", 
parameters=[ 
  {"name": "@embedding", "value": search_query_embedded} 
 ], 
 enable_cross_partition_query=True)


for item in items:
    print(item)
# Out:
# {'fileName': 'wine_Il_Colle_2010__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8451014622349144}
# {'fileName': 'wine_Agricoltori_del_Chianti_Geografico_2005_Riserva_Montegiachi__(Chianti_Classico).csv', 'textSimilarityScore': 0.8427534398998414}
# {'fileName': 'wine_Biondi_Santi_2011__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8393854530631428}
# {'fileName': "wine_Masciarelli_2005_Valori__(Montepulciano_d'Abruzzo).csv", 'textSimilarityScore': 0.8382929831546151}
# {'fileName': 'wine_Armilla_2012__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8382018668116449}
# {'fileName': "wine_Mascarello_Giuseppe_e_Figlio_2008_Cà_d'Morissio_Riserva__(Barolo).csv", 'textSimilarityScore': 0.8381985831778174}
# {'fileName': 'wine_Antonio_Caggiano_2004_Vigna_Macchia_dei_Goti__(Taurasi).csv', 'textSimilarityScore': 0.837984985119633}
# {'fileName': 'wine_Casina_di_Cornia_2011__Chianti_Classico.csv', 'textSimilarityScore': 0.8378947473214258}
# {'fileName': 'wine_Tassi_2012__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8377638035266568}
# {'fileName': 'wine_Mazzei_2006_Fonterutoli__(Chianti_Classico).csv', 'textSimilarityScore': 0.8376715002032479}
# {'fileName': 'wine_Riecine_2011__Chianti_Classico.csv', 'textSimilarityScore': 0.8376039766453105}
# {'fileName': "wine_Tenuta_dell'Ornellaia_2004_Ornellaia__(Bolgheri_Superiore).csv", 'textSimilarityScore': 0.8366244904934}
# {'fileName': 'wine_Tenuta_di_Riseccoli_2011__Chianti_Classico.csv', 'textSimilarityScore': 0.8360031989853981}
# {'fileName': "wine_Podere_L'Aione_2004_Salve_Sangiovese_(Toscana).csv", 'textSimilarityScore': 0.8358555386089309}
# {'fileName': 'wine_Castello_di_Monsanto_2007_Il_Poggio_Riserva__(Chianti_Classico).csv', 'textSimilarityScore': 0.8353321418477283}
# {'fileName': 'wine_Mirù_2007__Ghemme.csv', 'textSimilarityScore': 0.8353229641222083}
# {'fileName': 'wine_Mirù_2007__Ghemme.csv', 'textSimilarityScore': 0.8353229641222083}
# {'fileName': 'wine_Le_Fraghe_2016_Rodon__(Bardolino_Chiaretto).csv', 'textSimilarityScore': 0.8351522130196632}
# {'fileName': 'wine_Feudi_di_San_Gregorio_2007_Sirica_Red_(Campania).csv', 'textSimilarityScore': 0.8346589849500268}
# {'fileName': 'wine_Vodopivec_2006_Classica_Vitovska_(Venezia_Giulia).csv', 'textSimilarityScore': 0.8344608526597905}
# {'fileName': 'wine_Michele_Satta_2008_Cavaliere_Sangiovese_(Toscana).csv', 'textSimilarityScore': 0.8344601311591151}
# {'fileName': 'wine_Botromagno_2005_Gravina_White_(Puglia).csv', 'textSimilarityScore': 0.8341418761160573}
# {'fileName': 'wine_Castelli_del_Grevepesa_2010_Lamole_Gran_Selezione__(Chianti_Classico).csv', 'textSimilarityScore': 0.8338414504072446}
# {'fileName': 'wine_Marchesi_Antinori_2010_Solaia_Red_(Toscana).csv', 'textSimilarityScore': 0.833710646447706}
# {'fileName': 'wine_Poliziano_2012__Vino_Nobile_di_Montepulciano.csv', 'textSimilarityScore': 0.8335855947807419}
# {'fileName': 'wine_Tenuta_San_Guido_2014_Sassicaia__(Bolgheri_Sassicaia).csv', 'textSimilarityScore': 0.8335142212163812}
# {'fileName': 'wine_Casa_al_Vento_2010_Foho_Riserva__(Chianti_Classico).csv', 'textSimilarityScore': 0.8332245487640334}
# {'fileName': 'wine_Gravner_2007_Ribolla_Ribolla_Gialla_(Venezia_Giulia).csv', 'textSimilarityScore': 0.8327112722946476}
# {'fileName': 'wine_La_Poderina_2011__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8326021079374057}
# {'fileName': 'wine_Proprietà_Sperino_2013_Uvaggio_Red_(Coste_della_Sesia).csv', 'textSimilarityScore': 0.8322356065072878}
# {'fileName': "wine_Marchesi_de'_Frescobaldi_2003_Castello_di_Pomino_Vendemmia_Tardiva_White_(Tuscany).csv", 'textSimilarityScore': 0.8321343357838207}
# {'fileName': 'wine_Tenute_Sella_2008_Omaggio_a_Quintino_Sella__(Lessona).csv', 'textSimilarityScore': 0.8318268678664434}
# {'fileName': 'wine_Tenuta_di_Trinoro_2012_Red_(Toscana).csv', 'textSimilarityScore': 0.831722613840575}
# {'fileName': 'wine_Fontodi_2013_Dino_Sangiovese_(Colli_della_Toscana_Centrale).csv', 'textSimilarityScore': 0.8315363284106786}
# {'fileName': "wine_L'Aietta_2012__Brunello_di_Montalcino.csv", 'textSimilarityScore': 0.8313323182216606}
# {'fileName': 'wine_Mascarello_Giuseppe_e_Figlio_2010_Monprivato__(Barolo).csv', 'textSimilarityScore': 0.8313315150628384}
# {'fileName': 'wine_Tre_Monti_2014_Vitalba_in_Anfora_Albana_(Romagna).csv', 'textSimilarityScore': 0.8311635429278657}
# {'fileName': 'wine_Castello_Banfi_1997__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8311539457673967}
# {'fileName': 'wine_Tre_Monti_2015_Vitalba_in_Anfora_Albana_(Romagna).csv', 'textSimilarityScore': 0.8310292251806615}
# {'fileName': 'wine_Il_Marroneto_2012_Madonna_delle_Grazie__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8302213398178316}
# {'fileName': 'wine_Marchesi_Antinori_2010_Tignanello_Red_(Toscana).csv', 'textSimilarityScore': 0.8300397316447796}
# {'fileName': "wine_Ca'_dei_Zago_2016_Col_Fondo_Glera.csv", 'textSimilarityScore': 0.8298601848291741}
# {'fileName': 'wine_Avignonesi_1995_Occhio_di_Pernice__(Vin_Santo_di_Montepulciano).csv', 'textSimilarityScore': 0.8297605914455074}
# {'fileName': 'wine_Arnaldo_Caprai_2007_25_Anni__(Sagrantino_di_Montefalco).csv', 'textSimilarityScore': 0.8296956004565889}
# {'fileName': 'wine_Moccagatta_2007_Basarin__(Barbaresco).csv', 'textSimilarityScore': 0.8295664157357656}
# {'fileName': 'wine_Il_Paradiso_di_Manfredi_2007__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8293336400332328}
# {'fileName': 'wine_San_Rustico_2009_Gaso__(Amarone_della_Valpolicella_Classico).csv', 'textSimilarityScore': 0.8291671542593853}
# {'fileName': 'wine_Tenuta_San_Guido_2004_Sassicaia__(Bolgheri_Sassicaia).csv', 'textSimilarityScore': 0.8290368658262428}
# {'fileName': "wine_Marchesi_de'_Frescobaldi_2013_Montesodi_Sangiovese_(Toscana).csv", 'textSimilarityScore': 0.8290353267336978}
# {'fileName': 'wine_Biondi_Santi_2010_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8288834411971273}
# {'fileName': 'wine_Rivetto_NV_Nebbiolo.csv', 'textSimilarityScore': 0.8288822697386612}
# {'fileName': 'wine_Le_Macchiole_2011_Messorio_Merlot_(Toscana).csv', 'textSimilarityScore': 0.8287729392248373}
# {'fileName': 'wine_Basilisco_2012_Storico__(Aglianico_del_Vulture).csv', 'textSimilarityScore': 0.8286281630041666}
# {'fileName': 'wine_Castello_di_Verrazzano_2012_Sassello_Gran_Selezione__(Chianti_Classico).csv', 'textSimilarityScore': 0.8285519950656642}
# {'fileName': 'wine_Giuseppe_Rinaldi_2013_Tre_Tine__(Barolo).csv', 'textSimilarityScore': 0.8283696073222888}
# {'fileName': 'wine_Cinciano_2010_Riserva__(Chianti_Classico).csv', 'textSimilarityScore': 0.8281313351086733}
# {'fileName': 'wine_Tenuta_di_Trinoro_2012_Palazzi_Merlot_(Toscana).csv', 'textSimilarityScore': 0.8281028139753441}
# {'fileName': 'wine_Cafaggio_2012__Chianti_Classico.csv', 'textSimilarityScore': 0.8279977176920177}
# {'fileName': 'wine_Sottimano_2012_Pajorè__(Barbaresco).csv', 'textSimilarityScore': 0.8279674704734168}
# {'fileName': 'wine_Bucci_2009_Villa_Bucci_Riserva__(Verdicchio_dei_Castelli_di_Jesi_Classico_Superiore).csv', 'textSimilarityScore': 0.8279039106375687}
# {'fileName': 'wine_Silvio_Grasso_2006_Ciabot_Manzoni__(Barolo).csv', 'textSimilarityScore': 0.8277172724259759}
# {'fileName': 'wine_San_Felice_2010_Poggio_Rosso_Riserva__(Chianti_Classico).csv', 'textSimilarityScore': 0.8276868836061543}
# {'fileName': 'wine_Biondi_Santi_2008__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8273927639515857}
# {'fileName': 'wine_Tenuta_Oliveto_2005_Il_Leccio_Sangiovese_(Toscana).csv', 'textSimilarityScore': 0.8273919205703932}
# {'fileName': 'wine_Ippolito_1845_1995_Ripe_del_Falco_Riserva_Superiore__(Cirò_Classico).csv', 'textSimilarityScore': 0.8271630355659144}
# {'fileName': 'wine_Le_Piane_2009__Boca.csv', 'textSimilarityScore': 0.8271601122162359}
# {'fileName': 'wine_Il_Paradiso_di_Manfredi_2007_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.827127011649264}
# {'fileName': 'wine_Ferrandes_2004__Passito_di_Pantelleria.csv', 'textSimilarityScore': 0.8268306989567231}
# {'fileName': 'wine_Tenuta_di_Biserno_2007_Il_Pino_di_Biserno_Red_(Toscana).csv', 'textSimilarityScore': 0.8267991933177645}
# {'fileName': 'wine_Tosti_2007_Cuvée_Giulio_I_Pinot_Nero_(Alta_Langa).csv', 'textSimilarityScore': 0.8266136093013494}
# {'fileName': 'wine_Antinori_1999_Guado_Al_Tasso__(Bolgheri).csv', 'textSimilarityScore': 0.8265523187201683}
# {'fileName': 'wine_Lisini_2011__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8264286482109935}
# {'fileName': 'wine_Le_Casematte_2014__Faro.csv', 'textSimilarityScore': 0.8263414355941365}
# {'fileName': 'wine_Allora_1999_Cielo_Red_(Napa_Valley).csv', 'textSimilarityScore': 0.8262984764769625}
# {'fileName': 'wine_Il_Palazzone_2010_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.826260951535264}
# {'fileName': 'wine_Mosolo_Gleni_2006_Pinot_Grigio_Pinot_Grigio_(Colli_Orientali_del_Friuli).csv', 'textSimilarityScore': 0.8262383020311621}
# {'fileName': 'wine_Pojer_&_Sandri_2005_Besler_Biank_White_(Vigneti_delle_Dolomiti).csv', 'textSimilarityScore': 0.8260817689279747}
# {'fileName': 'wine_Masseto_2011_Merlot_(Toscana).csv', 'textSimilarityScore': 0.8260466502085163}
# {'fileName': 'wine_Guastaferro_2007_Primum_Riserva__(Taurasi).csv', 'textSimilarityScore': 0.825987806102858}
# {'fileName': 'wine_Guastaferro_2008_Primum__(Taurasi).csv', 'textSimilarityScore': 0.8259412319562104}
# {'fileName': "news_Chinese_wine_tempts_Italy's_Illva.csv", 'textSimilarityScore': 0.8259112048155822}
# {'fileName': 'wine_Montenidoli_2014_Tradizionale__(Vernaccia_di_San_Gimignano).csv', 'textSimilarityScore': 0.8255857857284565}
# {'fileName': "wine_Tasca_d'Almerita_2007_Whitaker_Mozia_Grillo_(Sicilia).csv", 'textSimilarityScore': 0.8254121032565392}
# {'fileName': 'wine_Biondi_Santi_2013__Rosso_di_Montalcino.csv', 'textSimilarityScore': 0.8248279650765951}
# {'fileName': 'wine_Aldegheri_1995__Amarone_della_Valpolicella.csv', 'textSimilarityScore': 0.8246310121414178}
# {'fileName': "wine_Monteraponi_2010_Baron'_Ugo_Riserva__(Chianti_Classico).csv", 'textSimilarityScore': 0.8244368297185993}
# {'fileName': 'wine_Petra_1998_Riserva_Cabernet_Sauvignon-Merlot_(Toscana).csv', 'textSimilarityScore': 0.8243817746924428}
# {'fileName': 'wine_Piccini_2005_Riserva__(Chianti_Classico).csv', 'textSimilarityScore': 0.8242555153649725}
# {'fileName': 'wine_Silvio_Grasso_2006_Bricco_Luciani__(Barolo).csv', 'textSimilarityScore': 0.8240683235908601}
# {'fileName': "wine_Ca'_dei_Zago_2013_Col_Fondo__(Prosecco).csv", 'textSimilarityScore': 0.8240087049448279}
# {'fileName': "wine_Ca'_dei_Zago_2013_Col_Fondo__(Prosecco).csv", 'textSimilarityScore': 0.8240087049448279}
# {'fileName': 'wine_Ornellaia_2013__Bolgheri_Superiore.csv', 'textSimilarityScore': 0.8239848418752214}
# {'fileName': 'wine_Maculan_2009_Fratta_Red_(Veneto).csv', 'textSimilarityScore': 0.8238627063533702}
# {'fileName': 'wine_Quintarelli_2003__Amarone_della_Valpolicella_Classico.csv', 'textSimilarityScore': 0.8236977885995985}
# {'fileName': 'wine_Luigi_Oddero_&_Figli_2008_Vigna_Rionda__(Barolo).csv', 'textSimilarityScore': 0.8236675707071993}
# {'fileName': 'wine_Le_Macchiole_2010_Paleo_Rosso_Cabernet_Franc_(Toscana).csv', 'textSimilarityScore': 0.8235843358228522}
# {'fileName': 'wine_Il_Colle_2011__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8234409765588603}
# {'fileName': 'wine_Casanova_di_Neri_2007_Cerretalto__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8232275988164801}
# {'fileName': 'wine_Baricci_2010_Nello_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8231266794186443}
# {'fileName': 'wine_Giacosa_Fratelli_2003_Bussia__(Barolo).csv', 'textSimilarityScore': 0.8229784313686821}
# {'fileName': 'wine_Cantina_Terlano_2000_Winkle_Sauvignon_Blanc_(Alto_Adige).csv', 'textSimilarityScore': 0.8229403195224786}
# {'fileName': 'wine_Cantina_Bartolo_Mascarello_2012__Barolo.csv', 'textSimilarityScore': 0.8228405490071867}
# {'fileName': 'wine_Le_Chiuse_2012__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8228266655226089}
# {'fileName': 'wine_Felsina_2010_Colonia_Gran_Selezione__(Chianti_Classico).csv', 'textSimilarityScore': 0.8227482566912292}
# {'fileName': 'wine_Grimaldi_Bruna_2013_Badarina__(Barolo).csv', 'textSimilarityScore': 0.8226557035514521}
# {'fileName': "wine_Chiarito_2007_Estate_Bottled_Nero_d'Avola_(Mendocino).csv", 'textSimilarityScore': 0.822573888084945}
# {'fileName': 'wine_Proprietà_Sperino_2011__Lessona.csv', 'textSimilarityScore': 0.8224606663777032}
# {'fileName': 'wine_Michele_Chiarlo_2011_Cerequio__(Barolo).csv', 'textSimilarityScore': 0.8224055610392929}
# {'fileName': 'wine_Gravner_2005_Anfora_Breg_White_(Venezia_Giulia).csv', 'textSimilarityScore': 0.8221887860306883}
# {'fileName': "wine_Cent'Anni_2014_Buoni_Anni_Bianco_White_(Santa_Ynez_Valley).csv", 'textSimilarityScore': 0.8220492473261437}
# {'fileName': 'wine_Gravner_2005_Amfora_Ribolla_Gialla_(Venezia_Giulia).csv', 'textSimilarityScore': 0.8220130947874427}
# {'fileName': 'wine_Le_Ragnaie_2012_VV__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8217244064782004}
# {'fileName': 'wine_Speri_2004_La_Roggia__(Recioto_della_Valpolicella_Classico).csv', 'textSimilarityScore': 0.8215088965397318}
# {'fileName': 'wine_Antica_2007_Antinori_Family_Estate_Red_(Napa_Valley).csv', 'textSimilarityScore': 0.8213781802354105}
# {'fileName': 'wine_Vallana_2006__Gattinara.csv', 'textSimilarityScore': 0.8212201873586137}
# {'fileName': 'wine_Paternoster_2004_Riserva_Don_Anselmo__(Aglianico_del_Vulture).csv', 'textSimilarityScore': 0.8211598773707997}
# {'fileName': 'wine_Colutta_2006_Sauvignon_(Colli_Orientali_del_Friuli).csv', 'textSimilarityScore': 0.820991728311544}
# {'fileName': 'wine_Sottimano_2013_Cottà__(Barbaresco).csv', 'textSimilarityScore': 0.820951169465918}
# {'fileName': 'wine_Sottimano_2010_Riserva__(Barbaresco).csv', 'textSimilarityScore': 0.8208878203558341}
# {'fileName': 'wine_Ornellaia_2010__Bolgheri_Superiore.csv', 'textSimilarityScore': 0.8208697751652825}
# {'fileName': "wine_Castello_dei_Rampolla_2012_d'Alceo_Red_(Toscana).csv", 'textSimilarityScore': 0.8208638969154771}
# {'fileName': 'wine_Nino_Negri_2013_5_Stelle__(Sforzato_di_Valtellina).csv', 'textSimilarityScore': 0.8207623942536025}
# {'fileName': 'wine_Giuseppe_Rinaldi_2012_Brunate__(Barolo).csv', 'textSimilarityScore': 0.8207308036026426}
# {'fileName': 'wine_Contrade_di_Taurasi_-_Lonardo_2010__Taurasi.csv', 'textSimilarityScore': 0.8207142094418287}
# {'fileName': "wine_Tasca_d'Almerita_1998_Rosso_del_Conte_Red_(Sicilia).csv", 'textSimilarityScore': 0.820707548480741}
# {'fileName': 'wine_Fanti_1997__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8201912296329772}
# {'fileName': 'wine_Cascina_delle_Rose_2012_Rio_Sordo__(Barbaresco).csv', 'textSimilarityScore': 0.8201520532601208}
# {'fileName': 'wine_Ronco_del_Gelso_2011_Vigna_della_Permuta_Malvasia_(Isonzo_del_Friuli).csv', 'textSimilarityScore': 0.8201390548683565}
# {'fileName': 'wine_Biondi_Santi_2011_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8200630207741599}
# {'fileName': 'wine_Palari_2010__Faro.csv', 'textSimilarityScore': 0.8200301134429141}
# {'fileName': 'wine_Giacomo_Ascheri_2001_Sorano_Coste_&_Bricco__(Barolo).csv', 'textSimilarityScore': 0.8198806850119453}
# {'fileName': "wine_Tenuta_dell'Ornellaia_2007_Masseto_Merlot_(Toscana).csv", 'textSimilarityScore': 0.8198494891848083}
# {'fileName': "wine_Ca'_Marcanda_2010_Camarcanda__(Bolgheri).csv", 'textSimilarityScore': 0.8198400568021073}
# {'fileName': 'wine_Teruzzi_&_Puthod_2011_Riserva__(Vernaccia_di_San_Gimignano).csv', 'textSimilarityScore': 0.8196276148456355}
# {'fileName': "wine_Col_d'Orcia_2006_Poggio_al_Vento_Riserva__(Brunello_di_Montalcino).csv", 'textSimilarityScore': 0.8190898671923246}
# {'fileName': 'wine_Dal_Forno_Romano_2006__Amarone_della_Valpolicella.csv', 'textSimilarityScore': 0.8189747252961554}
# {'fileName': 'wine_Tenuta_San_Guido_2010_Sassicaia__(Bolgheri_Sassicaia).csv', 'textSimilarityScore': 0.8186518083629312}
# {'fileName': 'wine_Mastroberardino_2008_Radici_Antonio_Riserva__(Taurasi).csv', 'textSimilarityScore': 0.8186065941330873}
# {'fileName': 'wine_Massolino_2011_Vigna_Rionda_Riserva__(Barolo).csv', 'textSimilarityScore': 0.818469517872798}
# {'fileName': 'wine_Feudi_di_San_Gregorio_2012_Patrimo_Merlot_(Campania).csv', 'textSimilarityScore': 0.818387251271803}
# {'fileName': 'wine_Antichi_Vigneti_di_Cantalupo_2006_Collis_Breclemae__(Ghemme).csv', 'textSimilarityScore': 0.8182158261677014}
# {'fileName': 'wine_Soldera_2001_Case_Basse__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.818186223262541}
# {'fileName': 'wine_Giuseppe_Rinaldi_2013_Brunate__(Barolo).csv', 'textSimilarityScore': 0.8181484685118987}
# {'fileName': 'wine_Terlan_2004_Rarità_2004_Pinot_Bianco_(Alto_Adige).csv', 'textSimilarityScore': 0.8177673786997874}
# {'fileName': 'wine_Il_Marroneto_2009_Madonna_delle_Grazie__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8177349397184649}
# {'fileName': 'wine_Paltrinieri_2016_Radice__(Lambrusco_di_Sorbara).csv', 'textSimilarityScore': 0.8175563455237358}
# {'fileName': 'wine_Biondi_Santi_2007_Riserva__(Brunello_di_Montalcino).csv', 'textSimilarityScore': 0.8173387560355769}
# {'fileName': 'wine_Giacomo_Fenocchio_2008_Bussia_90_Dì__(Barolo).csv', 'textSimilarityScore': 0.8173168260208772}
# {'fileName': 'wine_Beni_di_Batasiolo_2000_Vigneto_Boscareto__(Barolo).csv', 'textSimilarityScore': 0.8172870529937674}
# {'fileName': 'wine_Tedeschi_2011_La_Fabriseria_Riserva__(Amarone_della_Valpolicella_Classico).csv', 'textSimilarityScore': 0.8170782933477921}
# {'fileName': 'wine_Gargiulo_2005_Aprile_Red_(Oakville).csv', 'textSimilarityScore': 0.8170051084821354}
# {'fileName': 'wine_Benanti_2014_Rosso__(Etna).csv', 'textSimilarityScore': 0.8169187775038926}
# {'fileName': 'wine_Giacomo_Fenocchio_2013_Bussia__(Barolo).csv', 'textSimilarityScore': 0.8168595122304296}
# {'fileName': 'wine_Livio_Felluga_2004_Picolit_Picolit_(Colli_Orientali_del_Friuli).csv', 'textSimilarityScore': 0.8168285284002114}
# {'fileName': 'wine_Fontodi_2013_Vigna_del_Sorbo_Gran_Selezione__(Chianti_Classico).csv', 'textSimilarityScore': 0.8166926245507822}
# {'fileName': 'wine_Cavallotto_2014_Nebbiolo_(Langhe).csv', 'textSimilarityScore': 0.8166566499296579}
# {'fileName': 'wine_Tre_Nova_2009_Ripasso_Red_(Columbia_Valley_(WA)).csv', 'textSimilarityScore': 0.8165614637682163}
# {'fileName': 'wine_Goretti_2003_Le_Mura_Saracene__(Sagrantino_di_Montefalco).csv', 'textSimilarityScore': 0.8164457323810705}
# {'fileName': 'wine_Monteverro_2011_Tinata_Red_(Toscana).csv', 'textSimilarityScore': 0.8161971812514698}
# {'fileName': 'wine_Brezza_2013_Cannubi__(Barolo).csv', 'textSimilarityScore': 0.8161602522784683}
# {'fileName': 'wine_Ceretto_2012_Bricco_Rocche__(Barolo).csv', 'textSimilarityScore': 0.8160407975893859}
# {'fileName': 'wine_Attilio_Ghisolfi_2011_Bussia_Bricco_Visette__(Barolo).csv', 'textSimilarityScore': 0.8159917476758114}
# {'fileName': 'wine_La_Prevostura_2011__Bramaterra.csv', 'textSimilarityScore': 0.815711863085468}
# {'fileName': 'wine_Albis_2003_Cabernet_Sauvignon-Carmenère_(Maipo_Valley).csv', 'textSimilarityScore': 0.8156858972450908}
# {'fileName': 'wine_Cavallotto_2013_Bricco_Boschis__(Barolo).csv', 'textSimilarityScore': 0.8153396206809406}
# {'fileName': 'wine_Fontodi_2013_Flaccianello_della_Pieve_Sangiovese_(Colli_della_Toscana_Centrale).csv', 'textSimilarityScore': 0.8153028822455803}
# {'fileName': 'wine_Talenti_1997__Brunello_di_Montalcino.csv', 'textSimilarityScore': 0.8153008903222189}
# {'fileName': 'wine_Elvio_Cogno_2010_Bricco_Pernice__(Barolo).csv', 'textSimilarityScore': 0.8152381425377077}
# {'fileName': 'wine_Dal_Forno_Romano_2004_Vigneto_di_Monte_Lodoletta__(Amarone_della_Valpolicella).csv', 'textSimilarityScore': 0.8148335966682734}
# {'fileName': 'wine_Frank_Cornelissen_2012_MunJebel_9_VA_Nerello_Mascalese_(Vino_da_Tavola).csv', 'textSimilarityScore': 0.8148147479161375}
# {'fileName': 'wine_Uvaggio_2013_dolce_Moscato_(Lodi).csv', 'textSimilarityScore': 0.8146879631279366}
# {'fileName': 'wine_Comm._G._B._Burlotto_2013_Acclivi__(Barolo).csv', 'textSimilarityScore': 0.8145685395246116}
# {'fileName': 'wine_Gaja_2006_Costa_Russi_Nebbiolo_(Langhe).csv', 'textSimilarityScore': 0.8141291102376699}
# {'fileName': 'wine_Uvaggio_2009_Moscato_Secco_Moscato_(Lodi).csv', 'textSimilarityScore': 0.8137189272389501}
# {'fileName': 'wine_Failla_2010_Estate_Vineyard_Chardonnay_(Sonoma_Coast).csv', 'textSimilarityScore': 0.8136421669873615}
# {'fileName': 'wine_Passopisciaro_2013_Contrada_R_Nerello_Mascalese_(Terre_Siciliane).csv', 'textSimilarityScore': 0.8136168278970826}
# {'fileName': 'wine_Allora_1999_Tresca_Cabernet_Sauvignon_(Napa_Valley).csv', 'textSimilarityScore': 0.8134712393448711}
# {'fileName': 'wine_Monte_De_Oro_2011_Vigna_Vicini_Reserve_Red_(Temecula_Valley).csv', 'textSimilarityScore': 0.8133493354634399}
# {'fileName': 'wine_Castello_di_Ama_2010_San_Lorenzo_Gran_Selezione__(Chianti_Classico).csv', 'textSimilarityScore': 0.8131729905340201}
# {'fileName': 'wine_Massolino_2013_Parussi__(Barolo).csv', 'textSimilarityScore': 0.8130459596767045}
# {'fileName': 'wine_Dal_Forno_Romano_2007__Valpolicella_Superiore.csv', 'textSimilarityScore': 0.8130005553439115}
# {'fileName': "wine_Tenuta_dell'Ornellaia_2004_Masseto_Merlot_(Toscana).csv", 'textSimilarityScore': 0.812636311856043}
# {'fileName': "wine_Marchesi_de'_Frescobaldi_2012_Lamaione_Red_(Toscana).csv", 'textSimilarityScore': 0.8125103009793306}
# {'fileName': 'wine_Feudi_di_San_Gregorio_2007_Pátrimo_Merlot_(Campania).csv', 'textSimilarityScore': 0.8122118797545322}
# {'fileName': 'wine_Testarossa_2011_Pisoni_Vineyard_Pinot_Noir_(Santa_Lucia_Highlands).csv', 'textSimilarityScore': 0.8116511415535732}
# {'fileName': 'wine_Gaja_2013__Barbaresco.csv', 'textSimilarityScore': 0.8115584905730842}
# {'fileName': 'wine_Bride_Valley_Vineyard_2014_Rosé_Bella_Sparkling_(England).csv', 'textSimilarityScore': 0.8114992500287793}
# {'fileName': 'wine_Borgo_Scopeto_1998_Borgonero_Sangiovese_(Toscana).csv', 'textSimilarityScore': 0.8112876975765245}
# {'fileName': 'wine_Arpepe_2007_Sassella_Vigna_Regina_Riserva__(Valtellina_Superiore).csv', 'textSimilarityScore': 0.810950061169671}
# {'fileName': 'wine_Gaja_2012__Barbaresco.csv', 'textSimilarityScore': 0.8107562022876543}
# {'fileName': 'wine_Massolino_2013_Parafada__(Barolo).csv', 'textSimilarityScore': 0.8106675894552561}
# {'fileName': 'wine_Liparita_2012_V_Block_Cabernet_Sauvignon_(Yountville).csv', 'textSimilarityScore': 0.8103878526890621}
# {'fileName': 'wine_Comm._G._B._Burlotto_2013_Monvigliero__(Barolo).csv', 'textSimilarityScore': 0.810189464589674}
# {'fileName': 'wine_Gary_Farrell_2009_Rochioli_Vineyard_Chardonnay_(Russian_River_Valley).csv', 'textSimilarityScore': 0.8086827991635263}
# {'fileName': 'wine_Palmina_2009_Nebbiolo_(Santa_Barbara_County).csv', 'textSimilarityScore': 0.8080195062175306}
# {'fileName': 'wine_Alexander_2009_The_Great_Amarolo_Red_(Israel).csv', 'textSimilarityScore': 0.8078919808048853}
# {'fileName': 'wine_Three_Fox_2007_Piemontese_Nebbiolo_(Virginia).csv', 'textSimilarityScore': 0.8078811278311728}
# {'fileName': 'wine_Giacomo_Conterno_2011_Francia__(Barolo).csv', 'textSimilarityScore': 0.8077539515305335}
# {'fileName': 'wine_Anthony_Nappa_2013_Giallo_Sémillon_(North_Fork_of_Long_Island).csv', 'textSimilarityScore': 0.8076169496251246}
# {'fileName': 'wine_Mauro_2002_Vendimia_Seleccionada_Tempranillo_(Vino_de_la_Tierra_de_Castilla_y_León).csv', 'textSimilarityScore': 0.8073514509803835}

# %%
questions = ["Give me a list of books published in the year 2000",
"Give me a list of book of travel category",
"Give me a list of books from author Agatha Christie",
"Give me some haunted incidents from california state",
"Give me some wines found in Italy",
"Give me wines tasted by Roger Voss",
"Give me some wines in the variety of Red Blend",
"Give me some business category news",
"Give me a list of students graduated in the year 2025"]

# %%
# %%skip
# import os
# question_index = 1
#
# print(f"Question: {questions[question_index]}")
# with open(os.path.join("questions", f'question{question_index + 1}.txt'), 'r') as file:
#     q1_lines = [line.strip() for line in file if line.strip()]
#
# # Flatten multi-line entries (like Janet_My_Mother_and_Me.csv)
# from itertools import groupby
#
# q1_files = []
# temp = []
# for line in q1_lines:
#     temp.append(line.replace("txt", "csv"))
#     if line.endswith('.txt'):
#         q1_files.append('_'.join(temp))
#         temp = []
# search_query = questions[question_index]
# embedding_result = await openai_helper.generate_embeddings([search_query], model="text-embedding-ada-002")
# search_query_embedded = embedding_result[0].embedding
# search_query_arr = search_query.split(" ")
# print(search_query_arr)

# %%
# %%skip
#
# print(search_query_arr)
# query_string = f"""
# SELECT TOP 400 c.fileName
# FROM c
# ORDER BY RANK FullTextScore(c.text, {search_query_arr})
# """
#
# items = container.query_items(
#     query=query_string,
#     parameters=[
#         #{"name": "@searchTerms", "value": search_query_arr}
#     ],
#     enable_cross_partition_query=True
# )
#
# item_files = [item for item in items]
#
# for item in item_files:
#     print(item)

# %%
print(len(q1_files))
# Out:
# 181

# %% [markdown]
# ### Hybrid Search

# %%
# %%skip
# print(f"query:{search_query}")
# items = container.query_items(
# query=f"""SELECT top 50 c.fileName
# FROM c
#
# ORDER BY RANK RRF(VectorDistance(c.textVector, {search_query_embedded}),  FullTextScore(c.text, {search_query_arr}))
# """,
# parameters=[
#   #{"name": "@embedding", "value": search_query_embedded},
#   #{"name": "@search_query_arr", "value": search_query_arr}
#  ],
#  enable_cross_partition_query=True)
#
# item_files = [item for item in items]
#
# print(f"Number of files in database: {len(item_files)}")

# %% [markdown]
# ## Evaluation

# %%
q1_set = set(q1_files)
item_files_set = {item['fileName'] for item in combined_results}

missing_in_items = q1_set - item_files_set
extra_in_items = item_files_set - q1_set

print("Count of files in q1.txt but missing in search:", len(missing_in_items))

# recall percentage
recall = len(q1_set) / (len(q1_set) + len(missing_in_items)) * 100
print(f"Recall: {recall:.2f}%")
print("Files in q1.txt but missing in search:")
for f in sorted(missing_in_items):
    print(f)
# Out:
# Count of files in q1.txt but missing in search: 181
# Recall: 50.00%
# Files in q1.txt but missing in search:
# wine_Agricoltori del Chianti Geografico 2005 Riserva Montegiachi  (Chianti Classico).csv
# wine_Aldegheri 1995  Amarone della Valpolicella.csv
# wine_Antichi Vigneti di Cantalupo 2006 Collis Breclemae  (Ghemme).csv
# wine_Antinori 1999 Guado Al Tasso  (Bolgheri).csv
# wine_Antonio Caggiano 2004 Vigna Macchia dei Goti  (Taurasi).csv
# wine_Armilla 2012  Brunello di Montalcino.csv
# wine_Arnaldo Caprai 2007 25 Anni  (Sagrantino di Montefalco).csv
# wine_Arpepe 2007 Sassella Vigna Regina Riserva  (Valtellina Superiore).csv
# wine_Attilio Ghisolfi 2011 Bussia Bricco Visette  (Barolo).csv
# wine_Avignonesi 1995 Occhio di Pernice  (Vin Santo di Montepulciano).csv
# wine_Baricci 2010 Nello Riserva  (Brunello di Montalcino).csv
# wine_Basilisco 2012 Storico  (Aglianico del Vulture).csv
# wine_Benanti 2014 Rosso  (Etna).csv
# wine_Beni di Batasiolo 2000 Vigneto Boscareto  (Barolo).csv
# wine_Biondi Santi 2007 Riserva  (Brunello di Montalcino).csv
# wine_Biondi Santi 2008  Brunello di Montalcino.csv
# wine_Biondi Santi 2010 Riserva  (Brunello di Montalcino).csv
# wine_Biondi Santi 2011  Brunello di Montalcino.csv
# wine_Biondi Santi 2011 Riserva  (Brunello di Montalcino).csv
# wine_Biondi Santi 2013  Rosso di Montalcino.csv
# wine_Borgo Scopeto 1998 Borgonero Sangiovese (Toscana).csv
# wine_Botromagno 2005 Gravina White (Puglia).csv
# wine_Brezza 2013 Cannubi  (Barolo).csv
# wine_Brezza 2013 Sarmassa  (Barolo).csv
# wine_Bucci 2009 Villa Bucci Riserva  (Verdicchio dei Castelli di Jesi Classico Superiore).csv
# wine_Ca' Marcanda 2010 Camarcanda  (Bolgheri).csv
# wine_Ca' dei Zago 2013 Col Fondo  (Prosecco).csv
# wine_Ca' dei Zago 2016 Col Fondo Glera.csv
# wine_Cafaggio 2012  Chianti Classico.csv
# wine_Cantina Bartolo Mascarello 2012  Barolo.csv
# wine_Cantina Terlano 2000 Winkle Sauvignon Blanc (Alto Adige).csv
# wine_Casa al Vento 2010 Foho Riserva  (Chianti Classico).csv
# wine_Casanova di Neri 2007 Cerretalto  (Brunello di Montalcino).csv
# wine_Cascina delle Rose 2012 Rio Sordo  (Barbaresco).csv
# wine_Casina di Cornia 2011  Chianti Classico.csv
# wine_Castelli del Grevepesa 2010 Lamole Gran Selezione  (Chianti Classico).csv
# wine_Castello Banfi 1997  Brunello di Montalcino.csv
# wine_Castello dei Rampolla 2012 d'Alceo Red (Toscana).csv
# wine_Castello di Ama 2010 San Lorenzo Gran Selezione  (Chianti Classico).csv
# wine_Castello di Monsanto 2007 Il Poggio Riserva  (Chianti Classico).csv
# wine_Castello di Verrazzano 2012 Sassello Gran Selezione  (Chianti Classico).csv
# wine_Cavallotto 2013 Bricco Boschis  (Barolo).csv
# wine_Cavallotto 2014 Nebbiolo (Langhe).csv
# wine_Ceretto 2012 Bricco Rocche  (Barolo).csv
# wine_Cinciano 2010 Riserva  (Chianti Classico).csv
# wine_Col d'Orcia 2006 Poggio al Vento Riserva  (Brunello di Montalcino).csv
# wine_Colutta 2006 Sauvignon (Colli Orientali del Friuli).csv
# wine_Comm. G. B. Burlotto 2013 Acclivi  (Barolo).csv
# wine_Comm. G. B. Burlotto 2013 Monvigliero  (Barolo).csv
# wine_Contrade di Taurasi - Lonardo 2010  Taurasi.csv
# wine_Dal Forno Romano 2004 Vigneto di Monte Lodoletta  (Amarone della Valpolicella).csv
# wine_Dal Forno Romano 2006  Amarone della Valpolicella.csv
# wine_Dal Forno Romano 2007  Valpolicella Superiore.csv
# wine_Elvio Cogno 2010 Bricco Pernice  (Barolo).csv
# wine_Fanti 1997  Brunello di Montalcino.csv
# wine_Felsina 2010 Colonia Gran Selezione  (Chianti Classico).csv
# wine_Ferrandes 2004  Passito di Pantelleria.csv
# wine_Feudi di San Gregorio 2007 Pátrimo Merlot (Campania).csv
# wine_Feudi di San Gregorio 2007 Sirica Red (Campania).csv
# wine_Feudi di San Gregorio 2012 Patrimo Merlot (Campania).csv
# wine_Fontodi 2013 Dino Sangiovese (Colli della Toscana Centrale).csv
# wine_Fontodi 2013 Flaccianello della Pieve Sangiovese (Colli della Toscana Centrale).csv
# wine_Fontodi 2013 Vigna del Sorbo Gran Selezione  (Chianti Classico).csv
# wine_Frank Cornelissen 2012 MunJebel 9 VA Nerello Mascalese (Vino da Tavola).csv
# wine_Gaja 2006 Costa Russi Nebbiolo (Langhe).csv
# wine_Gaja 2006 Sperss Nebbiolo (Langhe).csv
# wine_Gaja 2012  Barbaresco.csv
# wine_Gaja 2013  Barbaresco.csv
# wine_Giacomo Ascheri 2001 Sorano Coste & Bricco  (Barolo).csv
# wine_Giacomo Conterno 2011 Francia  (Barolo).csv
# wine_Giacomo Fenocchio 2008 Bussia 90 Dì  (Barolo).csv
# wine_Giacomo Fenocchio 2013 Bussia  (Barolo).csv
# wine_Giacosa Fratelli 2003 Bussia  (Barolo).csv
# wine_Giuseppe Rinaldi 2012 Brunate  (Barolo).csv
# wine_Giuseppe Rinaldi 2013 Brunate  (Barolo).csv
# wine_Giuseppe Rinaldi 2013 Tre Tine  (Barolo).csv
# wine_Goretti 2003 L'Arringatore Red (Colli Perugini).csv
# wine_Goretti 2003 Le Mura Saracene  (Sagrantino di Montefalco).csv
# wine_Gravner 2005 Amfora Ribolla Gialla (Venezia Giulia).csv
# wine_Gravner 2005 Anfora Breg White (Venezia Giulia).csv
# wine_Gravner 2007 Ribolla Ribolla Gialla (Venezia Giulia).csv
# wine_Grimaldi Bruna 2013 Badarina  (Barolo).csv
# wine_Guastaferro 2007 Primum Riserva  (Taurasi).csv
# wine_Guastaferro 2008 Primum  (Taurasi).csv
# wine_Il Colle 2010  Brunello di Montalcino.csv
# wine_Il Colle 2011  Brunello di Montalcino.csv
# wine_Il Marroneto 2009 Madonna delle Grazie  (Brunello di Montalcino).csv
# wine_Il Marroneto 2012 Madonna delle Grazie  (Brunello di Montalcino).csv
# wine_Il Palazzone 2010 Riserva  (Brunello di Montalcino).csv
# wine_Il Paradiso di Manfredi 2007  Brunello di Montalcino.csv
# wine_Il Paradiso di Manfredi 2007 Riserva  (Brunello di Montalcino).csv
# wine_Ippolito 1845 1995 Ripe del Falco Riserva Superiore  (Cirò Classico).csv
# wine_L'Aietta 2012  Brunello di Montalcino.csv
# wine_La Poderina 2011  Brunello di Montalcino.csv
# wine_La Prevostura 2011  Bramaterra.csv
# wine_Le Casematte 2014  Faro.csv
# wine_Le Chiuse 2012  Brunello di Montalcino.csv
# wine_Le Fraghe 2016 Rodon  (Bardolino Chiaretto).csv
# wine_Le Macchiole 2010 Paleo Rosso Cabernet Franc (Toscana).csv
# wine_Le Macchiole 2011 Messorio Merlot (Toscana).csv
# wine_Le Piane 2009  Boca.csv
# wine_Le Ragnaie 2012 VV  (Brunello di Montalcino).csv
# wine_Lisini 2011  Brunello di Montalcino.csv
# wine_Livio Felluga 2004 Picolit Picolit (Colli Orientali del Friuli).csv
# wine_Luigi Oddero & Figli 2008 Vigna Rionda  (Barolo).csv
# wine_Maculan 2009 Fratta Red (Veneto).csv
# wine_Marchesi Antinori 2010 Solaia Red (Toscana).csv
# wine_Marchesi Antinori 2010 Tignanello Red (Toscana).csv
# wine_Marchesi de' Frescobaldi 2003 Castello di Pomino Vendemmia Tardiva White (Tuscany).csv
# wine_Marchesi de' Frescobaldi 2012 Lamaione Red (Toscana).csv
# wine_Marchesi de' Frescobaldi 2013 Montesodi Sangiovese (Toscana).csv
# wine_Mascarello Giuseppe e Figlio 2008 Cà d'Morissio Riserva  (Barolo).csv
# wine_Mascarello Giuseppe e Figlio 2010 Monprivato  (Barolo).csv
# wine_Masciarelli 2005 Valori  (Montepulciano d'Abruzzo).csv
# wine_Masseto 2011 Merlot (Toscana).csv
# wine_Massolino 2011 Vigna Rionda Riserva  (Barolo).csv
# wine_Massolino 2013 Parafada  (Barolo).csv
# wine_Massolino 2013 Parussi  (Barolo).csv
# wine_Mastroberardino 2008 Radici Antonio Riserva  (Taurasi).csv
# wine_Mazzei 2006 Fonterutoli  (Chianti Classico).csv
# wine_Michele Chiarlo 2011 Cerequio  (Barolo).csv
# wine_Michele Satta 2008 Cavaliere Sangiovese (Toscana).csv
# wine_Mirù 2007  Ghemme.csv
# wine_Moccagatta 2007 Basarin  (Barbaresco).csv
# wine_Montenidoli 2014 Tradizionale  (Vernaccia di San Gimignano).csv
# wine_Monteraponi 2010 Baron' Ugo Riserva  (Chianti Classico).csv
# wine_Monteverro 2011 Tinata Red (Toscana).csv
# wine_Mosolo Gleni 2006 Pinot Grigio Pinot Grigio (Colli Orientali del Friuli).csv
# wine_Nino Negri 2013 5 Stelle  (Sforzato di Valtellina).csv
# wine_Ornellaia 2010  Bolgheri Superiore.csv
# wine_Ornellaia 2013  Bolgheri Superiore.csv
# wine_Palari 2010  Faro.csv
# wine_Paltrinieri 2016 Radice  (Lambrusco di Sorbara).csv
# wine_Passopisciaro 2008 Passopisciaro Red (Sicilia).csv
# wine_Passopisciaro 2013 Contrada R Nerello Mascalese (Terre Siciliane).csv
# wine_Paternoster 2004 Riserva Don Anselmo  (Aglianico del Vulture).csv
# wine_Petra 1998 Riserva Cabernet Sauvignon-Merlot (Toscana).csv
# wine_Piccini 2005 Riserva  (Chianti Classico).csv
# wine_Podere L'Aione 2004 Salve Sangiovese (Toscana).csv
# wine_Pojer & Sandri 2005 Besler Biank White (Vigneti delle Dolomiti).csv
# wine_Poliziano 2012  Vino Nobile di Montepulciano.csv
# wine_Proprietà Sperino 2011  Lessona.csv
# wine_Proprietà Sperino 2013 Uvaggio Red (Coste della Sesia).csv
# wine_Quintarelli 2003  Amarone della Valpolicella Classico.csv
# wine_Remo Farina 1997 Ripasso  (Valpolicella Classico Superiore).csv
# wine_Riecine 2011  Chianti Classico.csv
# wine_Rivetto NV Nebbiolo.csv
# wine_Ronco del Gelso 2011 Vigna della Permuta Malvasia (Isonzo del Friuli).csv
# wine_San Felice 2010 Poggio Rosso Riserva  (Chianti Classico).csv
# wine_San Rustico 2009 Gaso  (Amarone della Valpolicella Classico).csv
# wine_Silvio Grasso 2006 Bricco Luciani  (Barolo).csv
# wine_Silvio Grasso 2006 Ciabot Manzoni  (Barolo).csv
# wine_Soldera 2001 Case Basse  (Brunello di Montalcino).csv
# wine_Sottimano 2010 Riserva  (Barbaresco).csv
# wine_Sottimano 2012 Pajorè  (Barbaresco).csv
# wine_Sottimano 2013 Cottà  (Barbaresco).csv
# wine_Speri 2004 La Roggia  (Recioto della Valpolicella Classico).csv
# wine_Talenti 1997  Brunello di Montalcino.csv
# wine_Tasca d'Almerita 1998 Rosso del Conte Red (Sicilia).csv
# wine_Tasca d'Almerita 2007 Whitaker Mozia Grillo (Sicilia).csv
# wine_Tassi 2012  Brunello di Montalcino.csv
# wine_Tedeschi 2011 La Fabriseria Riserva  (Amarone della Valpolicella Classico).csv
# wine_Tenuta Oliveto 2005 Il Leccio Sangiovese (Toscana).csv
# wine_Tenuta San Guido 2004 Sassicaia  (Bolgheri Sassicaia).csv
# wine_Tenuta San Guido 2010 Sassicaia  (Bolgheri Sassicaia).csv
# wine_Tenuta San Guido 2014 Sassicaia  (Bolgheri Sassicaia).csv
# wine_Tenuta dell'Ornellaia 2004 Masseto Merlot (Toscana).csv
# wine_Tenuta dell'Ornellaia 2004 Ornellaia  (Bolgheri Superiore).csv
# wine_Tenuta dell'Ornellaia 2007 Masseto Merlot (Toscana).csv
# wine_Tenuta di Biserno 2007 Il Pino di Biserno Red (Toscana).csv
# wine_Tenuta di Riseccoli 2011  Chianti Classico.csv
# wine_Tenuta di Trinoro 2012 Palazzi Merlot (Toscana).csv
# wine_Tenuta di Trinoro 2012 Red (Toscana).csv
# wine_Tenute Sella 2008 Omaggio a Quintino Sella  (Lessona).csv
# wine_Terlan 2004 Rarità 2004 Pinot Bianco (Alto Adige).csv
# wine_Teruzzi & Puthod 2011 Riserva  (Vernaccia di San Gimignano).csv
# wine_Tosti 2007 Cuvée Giulio I Pinot Nero (Alta Langa).csv
# wine_Tre Monti 2014 Vitalba in Anfora Albana (Romagna).csv
# wine_Tre Monti 2015 Vitalba in Anfora Albana (Romagna).csv
# wine_Vallana 2006  Gattinara.csv
# wine_Vodopivec 2006 Classica Vitovska (Venezia Giulia).csv

# %%
# %%skip
# print("Count of files in search but missing in q1.txt:", len(extra_in_items))
# print("Files in search but missing in q1.txt:")
# for f in sorted(extra_in_items):
#     print(f)
